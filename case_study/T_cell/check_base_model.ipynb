# %%
import pickle
import json
import time

from pystablemotifs.format import primes2bnet

from boolmore.eval.constraint import check_node
from boolmore.core.conversions import prime2rr

# %%
json_file = "Tcell_config.json"
CACHE_FILE = "Tcell_primes_ultrametric.pkl"

# %%
primes = pickle.load(open(CACHE_FILE, "rb"))

# %%
bnet = primes2bnet(primes)
print(bnet)
# Out:
# APC,            APC
# BCL6,           STAT1&STAT1_2&STAT3&STAT4&!STAT5&!TBET&!TBET_2&!TGFB
# CD28,           APC
# CD4,            NOTCH1&!RUNX3&THPOK
# CD8,            NOTCH1&RUNX3&!THPOK
# CMAF,           STAT3
# DLL1,           DLL1
# EOMES,          RUNX3
# FOXP3,          NFAT&SMAD2&SMAD3&STAT5&STAT5_2&!STAT6&!TBET&!TBET_2
# GATA3,          !BCL6&!FOXP3&GATA3&IL25R&!IL29R&NFAT&!PU1&STAT5&STAT5_2&STAT6&!TBET&!TBET_2
# GZMB,           EOMES
# IFNAR,          IFNA_e&IFNB_e
# IFNA_e,         IFNA_e
# IFNBR,          IFNB_e
# IFNB_e,         IFNB_e
# IFNG,           !BCL6&EOMES&!GATA3&IL18R&!IL9&IRAK&NFAT&NFKB&RUNX3&STAT4&TBET&TBET_2&proliferation
# IFNGR,          IFNG&IFNG_2&IFNG_e
# IFNGR_2,        IFNG&IFNGR&IFNG_2&IFNG_e
# IFNG_2,         !BCL6&EOMES&!GATA3&IFNG&IL18R&!IL9&IRAK&NFAT&NFKB&RUNX3&STAT4&TBET&TBET_2&proliferation
# IFNG_e,         IFNG_e
# IKB,            !TCR
# IL10,           CMAF&IRF1&NFAT&STAT3&proliferation
# IL10R,          IL10&IL10_e
# IL10_e,         IL10_e
# IL12R,          IL12RB1_2&IL12RB2&IL12_e
# IL12RB1_2,      IRF1
# IL12RB2,        !STAT6
# IL12_e,         IL12_e
# IL13,           GATA3&IL33R&NFAT&proliferation
# IL15R,          IL15_e
# IL15_e,         IL15_e
# IL17,           NFAT&NFKB&RORGT&STAT3&!STAT5&!STAT5_2&proliferation
# IL18R,          IL18_e&STAT4
# IL18_e,         IL18_e
# IL1R,           IL1R1&IL1_e
# IL1R1,          STAT3
# IL1_e,          IL1_e
# IL2,            !FOXP3&NFAT&NFKB&!TBET&!TBET_2
# IL21,           BCL6&CMAF&NFAT&STAT3&STAT4&proliferation
# IL21R,          IL21&IL21_e
# IL21_e,         IL21_e
# IL22,           !CMAF&NFAT&STAT3&proliferation
# IL23,           STAT3&proliferation
# IL23R,          IL23&IL23_e&RORGT&STAT3&!TBET&!TBET_2
# IL23_e,         IL23_e
# IL24,           STAT6&proliferation
# IL25,           GATA3&proliferation
# IL25R,          IL25&IL25_e
# IL25_e,         IL25_e
# IL27R,          IL27_e
# IL27_e,         IL27_e
# IL29R,          IL29_e
# IL29_e,         IL29_e
# IL2R,           IL2&IL2_e
# IL2RA,          FOXP3&NFAT&NFKB&SMAD3&STAT5
# IL2R_2,         IL2&IL2R&IL2RA&IL2_e
# IL2_e,          IL2_e
# IL3,            GATA3&NFAT&proliferation
# IL31,           NFAT&STAT6&proliferation
# IL33R,          IL33_e&ST2
# IL33_e,         IL33_e
# IL35,           FOXP3&proliferation
# IL36R,          IL36_e
# IL36_e,         IL36_e
# IL4,            CMAF&GATA3&!IRF1&NFAT&!RUNX3&STAT5&!TBET&!TBET_2&proliferation
# IL4R,           IL4&IL4_e
# IL4RA_2,        STAT5&STAT5_2
# IL4R_2,         IL4&IL4R&IL4RA_2&IL4_e
# IL4_e,          IL4_e
# IL5,            GATA3&IL33R&NFAT&proliferation
# IL6,            STAT3&proliferation
# IL6R,           IL6&IL6_e
# IL6_e,          IL6_e
# IL7R,           IL7_e&!TCR
# IL7_e,          IL7_e
# IL9,            IL33R&NFAT&NFKB&PU1&SMAD3&STAT6&proliferation
# IRAK,           IL18R
# IRF1,           STAT1&STAT1_2
# JAK1,           IFNGR&IFNGR_2&!SOCS1
# JAK3,           JAK3
# NFAT,           CD28&!FOXP3&TCR
# NFKB,           !FOXP3&!IKB&IRAK
# NOTCH1,         DLL1
# PRF1,           EOMES
# PU1,            TGFBR
# RORGT,          !FOXP3&!GATA3&RORGT&SMAD2&STAT3&!TBET&!TBET_2
# RUNX3,          CD8&STAT5&STAT5_2&!THPOK
# SMAD2,          TGFBR
# SMAD3,          TGFBR
# SOCS1,          STAT1&STAT1_2
# ST2,            GATA3
# STAT1,          IFNAR&IFNBR&IFNGR&IFNGR_2&IL27R&JAK1&STAT1
# STAT1_2,        IFNAR&IFNBR&IFNGR&IFNGR_2&IL27R&JAK1&STAT1
# STAT3,          IL10R&IL1R&IL21R&IL23R&IL27R&IL6R&JAK3
# STAT4,          !GATA3&IL12R
# STAT5,          IL15R&IL2R&IL2R_2&IL4R&IL7R&!SOCS1
# STAT5_2,        IL2R&IL2R_2&IL4R&IL4R_2&IL7R&!SOCS1&STAT5
# STAT6,          IL4R&IL4R_2&!SOCS1
# TBET,           !BCL6&!GATA3&IL36R&!IL9&STAT1&STAT1_2&STAT4
# TBET_2,         !BCL6&!GATA3&IL36R&!IL9&STAT1&STAT1_2&STAT4&TBET
# TCR,            APC
# TGFB,           NFAT&proliferation
# TGFBR,          TGFB&TGFB_e
# TGFB_e,         TGFB_e
# THPOK,          CD4&GATA3&!RUNX3&THPOK
# proliferation,  STAT5&STAT5_2&proliferation

# %%
regulators_dict = {}
rr_dict = {}
signs_dict = {}

for node in primes:
    regulators, rr, signs = prime2rr(primes[node])

    regulators_dict[node] = regulators
    rr_dict[node] = rr
    signs_dict[node] = signs

# %%
f = open(json_file)
json_dict = json.load(f)

constraints = json_dict["constraints"]

check = True
for node in primes:
    start = time.perf_counter()

    check = check_node(regulators_dict[node],
                       rr_dict[node],
                       rr_dict[node],
                       constraints,
                       node) and check

    end = time.perf_counter()
    print(f"Checking {node} took {end - start:.6f} seconds.")
# Out:
# Checking APC took 0.000010 seconds.
# Checking BCL6 took 0.001084 seconds.
# Checking CD28 took 0.000015 seconds.
# Checking CD4 took 0.000016 seconds.
# Checking CD8 took 0.000014 seconds.
# Checking CMAF took 0.000008 seconds.
# Checking DLL1 took 0.000002 seconds.
# Checking EOMES took 0.000007 seconds.
# Checking FOXP3 took 0.001035 seconds.
# Checking GATA3 took 0.037409 seconds.
# Checking GZMB took 0.000026 seconds.
# Checking IFNAR took 0.000019 seconds.
# Checking IFNA_e took 0.000002 seconds.
# Checking IFNBR took 0.000010 seconds.
# Checking IFNB_e took 0.000002 seconds.
# Checking IFNG took 0.055678 seconds.
# Checking IFNGR took 0.000070 seconds.
# Checking IFNGR_2 took 0.000089 seconds.
# Checking IFNG_2 took 0.151143 seconds.
# Checking IFNG_e took 0.000015 seconds.
# Checking IKB took 0.000031 seconds.
# Checking IL10 took 0.000057 seconds.
# Checking IL10R took 0.000014 seconds.
# Checking IL10_e took 0.000002 seconds.
# Checking IL12R took 0.000024 seconds.
# Checking IL12RB1_2 took 0.000008 seconds.
# Checking IL12RB2 took 0.000005 seconds.
# Checking IL12_e took 0.000001 seconds.
# Checking IL13 took 0.000022 seconds.
# Checking IL15R took 0.000017 seconds.
# Checking IL15_e took 0.000003 seconds.
# Checking IL17 took 0.000351 seconds.
# Checking IL18R took 0.000029 seconds.
# Checking IL18_e took 0.000002 seconds.
# Checking IL1R took 0.000016 seconds.
# Checking IL1R1 took 0.000006 seconds.
# Checking IL1_e took 0.000002 seconds.
# Checking IL2 took 0.000072 seconds.
# Checking IL21 took 0.000205 seconds.
# Checking IL21R took 0.000013 seconds.
# Checking IL21_e took 0.000001 seconds.
# Checking IL22 took 0.000039 seconds.
# Checking IL23 took 0.000015 seconds.
# Checking IL23R took 0.000189 seconds.
# Checking IL23_e took 0.000002 seconds.
# Checking IL24 took 0.000013 seconds.
# Checking IL25 took 0.000006 seconds.
# Checking IL25R took 0.000017 seconds.
# Checking IL25_e took 0.000002 seconds.
# Checking IL27R took 0.000011 seconds.
# Checking IL27_e took 0.000002 seconds.
# Checking IL29R took 0.000012 seconds.
# Checking IL29_e took 0.000002 seconds.
# Checking IL2R took 0.000018 seconds.
# Checking IL2RA took 0.000107 seconds.
# Checking IL2R_2 took 0.000068 seconds.
# Checking IL2_e took 0.000002 seconds.
# Checking IL3 took 0.000023 seconds.
# Checking IL31 took 0.000022 seconds.
# Checking IL33R took 0.000022 seconds.
# Checking IL33_e took 0.000002 seconds.
# Checking IL35 took 0.000007 seconds.
# Checking IL36R took 0.000012 seconds.
# Checking IL36_e took 0.000003 seconds.
# Checking IL4 took 0.002945 seconds.
# Checking IL4R took 0.000019 seconds.
# Checking IL4RA_2 took 0.000005 seconds.
# Checking IL4R_2 took 0.000041 seconds.
# Checking IL4_e took 0.000004 seconds.
# Checking IL5 took 0.000026 seconds.
# Checking IL6 took 0.000009 seconds.
# Checking IL6R took 0.000012 seconds.
# Checking IL6_e took 0.000002 seconds.
# Checking IL7R took 0.000012 seconds.
# Checking IL7_e took 0.000001 seconds.
# Checking IL9 took 0.000514 seconds.
# Checking IRAK took 0.000028 seconds.
# Checking IRF1 took 0.000033 seconds.
# Checking JAK1 took 0.000049 seconds.
# Checking JAK3 took 0.000004 seconds.
# Checking NFAT took 0.000047 seconds.
# Checking NFKB took 0.000030 seconds.
# Checking NOTCH1 took 0.000014 seconds.
# Checking PRF1 took 0.000014 seconds.
# Checking PU1 took 0.000008 seconds.
# Checking RORGT took 0.000656 seconds.
# Checking RUNX3 took 0.000051 seconds.
# Checking SMAD2 took 0.000015 seconds.
# Checking SMAD3 took 0.000016 seconds.
# Checking SOCS1 took 0.000014 seconds.
# Checking ST2 took 0.000008 seconds.
# Checking STAT1 took 0.000327 seconds.
# Checking STAT1_2 took 0.000988 seconds.
# Checking STAT3 took 0.001077 seconds.
# Checking STAT4 took 0.000061 seconds.
# Checking STAT5 took 0.000273 seconds.
# Checking STAT5_2 took 0.000583 seconds.
# Checking STAT6 took 0.000037 seconds.
# Checking TBET took 0.000201 seconds.
# Checking TBET_2 took 0.000880 seconds.
# Checking TCR took 0.000017 seconds.
# Checking TGFB took 0.000010 seconds.
# Checking TGFBR took 0.000023 seconds.
# Checking TGFB_e took 0.000006 seconds.
# Checking THPOK took 0.000049 seconds.
# Checking proliferation took 0.000021 seconds.
