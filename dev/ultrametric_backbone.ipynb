# %%
import csv
import networkx as nx

import distanceclosure as dc
from distanceclosure.dijkstra import single_source_dijkstra_path_length

# %%
csv_file_path = 'confidence_rank_unique.csv'
output_csv_path = 'confidence_rank_ultrametric.csv'
annotated_csv_path = 'confidence_rank_unique_annotated.csv'

source_col = 'Regulator'
target_col = 'Target'
weight_col = 'Confidence Rank'

# %%
edgelist = {}

with open(csv_file_path, mode='r', encoding='utf-8') as file:
    reader = csv.DictReader(file)
    for row in reader:
        # Create the tuple key using the source and target columns
        edge = (row[source_col], row[target_col])
        
        # Convert the weight to an integer (or float if needed)
        weight = int(row[weight_col])
        
        # Add to the dictionary
        edgelist[edge] = weight

print(edgelist)
print(len(edgelist))
# Out:
# {('APC', 'CD28'): 1, ('APC', 'TCR'): 1, ('BCL6', 'GATA3'): 1, ('BCL6', 'IFNG'): 1, ('BCL6', 'IFNG_2'): 1, ('BCL6', 'IL21'): 1, ('BCL6', 'RORGT'): 2, ('BCL6', 'TBET'): 1, ('BCL6', 'TBET_2'): 1, ('CD28', 'NFAT'): 1, ('CD4', 'CD4'): 4, ('CD4', 'RUNX3'): 3, ('CD4', 'THPOK'): 2, ('CD8', 'CD8'): 4, ('CD8', 'RUNX3'): 2, ('CD8', 'THPOK'): 3, ('CMAF', 'IL10'): 1, ('CMAF', 'IL13'): 2, ('CMAF', 'IL21'): 1, ('CMAF', 'IL22'): 1, ('CMAF', 'IL4'): 1, ('CMAF', 'IL5'): 2, ('DLL1', 'NOTCH1'): 1, ('EOMES', 'GZMB'): 1, ('EOMES', 'IFNG'): 1, ('EOMES', 'IFNG_2'): 1, ('EOMES', 'PRF1'): 1, ('FOXP3', 'FOXP3'): 2, ('FOXP3', 'GATA3'): 1, ('FOXP3', 'IFNG'): 2, ('FOXP3', 'IFNG_2'): 2, ('FOXP3', 'IL13'): 2, ('FOXP3', 'IL17'): 2, ('FOXP3', 'IL2'): 1, ('FOXP3', 'IL2RA'): 1, ('FOXP3', 'IL35'): 2, ('FOXP3', 'IL4'): 2, ('FOXP3', 'IL5'): 2, ('FOXP3', 'NFAT'): 1, ('FOXP3', 'NFKB'): 1, ('FOXP3', 'RORGT'): 1, ('FOXP3', 'TBET'): 4, ('FOXP3', 'TBET_2'): 4, ('FOXP3', 'TGFB'): 3, ('FOXP3', 'THPOK'): 4, ('GATA3', 'FOXP3'): 2, ('GATA3', 'GATA3'): 1, ('GATA3', 'IFNG'): 1, ('GATA3', 'IFNG_2'): 1, ('GATA3', 'IL10'): 2, ('GATA3', 'IL12R'): 2, ('GATA3', 'IL13'): 1, ('GATA3', 'IL25'): 4, ('GATA3', 'IL3'): 1, ('GATA3', 'IL4'): 1, ('GATA3', 'IL5'): 1, ('GATA3', 'RORGT'): 1, ('GATA3', 'ST2'): 1, ('GATA3', 'STAT4'): 1, ('GATA3', 'TBET'): 1, ('GATA3', 'TBET_2'): 1, ('GATA3', 'THPOK'): 1, ('IFNAR', 'STAT1'): 1, ('IFNAR', 'STAT1_2'): 1, ('IFNA_e', 'IFNAR'): 1, ('IFNBR', 'STAT1'): 1, ('IFNBR', 'STAT1_2'): 1, ('IFNB_e', 'IFNAR'): 1, ('IFNB_e', 'IFNBR'): 1, ('IFNG', 'GATA3'): 2, ('IFNG', 'IFNG'): 2, ('IFNG', 'IFNGR'): 1, ('IFNG', 'IFNGR_2'): 1, ('IFNG', 'IFNG_2'): 0, ('IFNG', 'IL10'): 2, ('IFNG', 'IL2'): 2, ('IFNG', 'IL21'): 2, ('IFNG', 'IL4'): 2, ('IFNG', 'IL9'): 2, ('IFNG', 'STAT6'): 2, ('IFNG', 'TBET'): 2, ('IFNG', 'TBET_2'): 2, ('IFNGR', 'IFNGR'): 2, ('IFNGR', 'IFNGR_2'): 0, ('IFNGR', 'JAK1'): 1, ('IFNGR', 'STAT1'): 1, ('IFNGR', 'STAT1_2'): 1, ('IFNGR_2', 'JAK1'): 1, ('IFNGR_2', 'STAT1'): 1, ('IFNGR_2', 'STAT1_2'): 1, ('IFNG_2', 'GATA3'): 2, ('IFNG_2', 'IFNGR'): 1, ('IFNG_2', 'IFNGR_2'): 1, ('IFNG_2', 'IFNG_2'): 2, ('IFNG_2', 'IL10'): 2, ('IFNG_2', 'IL2'): 2, ('IFNG_2', 'IL21'): 2, ('IFNG_2', 'IL4'): 2, ('IFNG_2', 'IL9'): 2, ('IFNG_2', 'STAT6'): 2, ('IFNG_2', 'TBET'): 2, ('IFNG_2', 'TBET_2'): 2, ('IFNG_e', 'IFNG'): 2, ('IFNG_e', 'IFNGR'): 1, ('IFNG_e', 'IFNGR_2'): 1, ('IFNG_e', 'IFNG_2'): 2, ('IKB', 'NFKB'): 1, ('IL10', 'IFNG'): 2, ('IL10', 'IFNG_2'): 2, ('IL10', 'IL10'): 2, ('IL10', 'IL10R'): 1, ('IL10', 'IL2'): 2, ('IL10', 'IL9'): 3, ('IL10R', 'STAT3'): 1, ('IL10_e', 'IL10'): 2, ('IL10_e', 'IL10R'): 1, ('IL12R', 'STAT4'): 1, ('IL12RB1_2', 'IL12R'): 0, ('IL12RB2', 'IL12R'): 0, ('IL12_e', 'IL12R'): 1, ('IL12_e', 'IL18R'): 2, ('IL12_e', 'STAT4'): 2, ('IL15R', 'STAT5'): 1, ('IL15_e', 'IL15R'): 1, ('IL18R', 'IFNG'): 2, ('IL18R', 'IFNG_2'): 2, ('IL18R', 'IRAK'): 1, ('IL18_e', 'IL18R'): 1, ('IL1R', 'STAT3'): 2, ('IL1R1', 'IL1R'): 0, ('IL1_e', 'IL1R'): 1, ('IL2', 'BCL6'): 2, ('IL2', 'FOXP3'): 2, ('IL2', 'GATA3'): 2, ('IL2', 'IL2'): 2, ('IL2', 'IL21'): 2, ('IL2', 'IL2R'): 1, ('IL2', 'IL2R_2'): 1, ('IL2', 'IL4'): 2, ('IL2', 'IL9'): 2, ('IL21', 'BCL6'): 2, ('IL21', 'FOXP3'): 2, ('IL21', 'GATA3'): 3, ('IL21', 'IFNG'): 3, ('IL21', 'IFNG_2'): 3, ('IL21', 'IL10'): 2, ('IL21', 'IL2'): 2, ('IL21', 'IL21'): 2, ('IL21', 'IL21R'): 1, ('IL21', 'IL9'): 3, ('IL21', 'RORGT'): 2, ('IL21R', 'FOXP3'): 2, ('IL21R', 'RORGT'): 2, ('IL21R', 'STAT3'): 1, ('IL21_e', 'IL21'): 2, ('IL21_e', 'IL21R'): 1, ('IL23', 'IL23R'): 1, ('IL23R', 'IL17'): 2, ('IL23R', 'STAT3'): 1, ('IL23_e', 'IL23R'): 1, ('IL25', 'IL25R'): 1, ('IL25R', 'GATA3'): 2, ('IL25_e', 'IL25R'): 1, ('IL27R', 'EOMES'): 2, ('IL27R', 'STAT1'): 1, ('IL27R', 'STAT1_2'): 1, ('IL27R', 'STAT3'): 1, ('IL27_e', 'IL27R'): 1, ('IL27_e', 'STAT1'): 2, ('IL27_e', 'STAT1_2'): 2, ('IL29R', 'GATA3'): 2, ('IL29_e', 'IL29R'): 1, ('IL2R', 'IL2R_2'): 0, ('IL2R', 'STAT5'): 1, ('IL2R', 'STAT5_2'): 1, ('IL2RA', 'IL2R_2'): 0, ('IL2R_2', 'STAT5'): 1, ('IL2R_2', 'STAT5_2'): 1, ('I ...
# 430

# %%
# edgelist = {
#     ('s', 'a'): 8,
#     ('s', 'c'): 6,
#     ('s', 'd'): 5,
#     ('a', 'd'): 2,
#     ('a', 'e'): 1,
#     ('b', 'e'): 6,
#     ('c', 'd'): 3,
#     ('c', 'f'): 9,
#     ('d', 'f'): 4,
#     ('e', 'g'): 4,
#     ('f', 'g'): 0,
# }

# %%
# Instanciate a (weighted) graph
G = nx.DiGraph()
weighted_edges = [(u, v, w) for (u, v), w in edgelist.items()]

G.add_weighted_edges_from(weighted_edges, weight='distance')

print(f"Nodes: {G.nodes()}")
print(f"Edges: {G.edges(data=True)}")
print(f"Number of nodes: {G.number_of_nodes()}")
print(f"Number of edges: {G.number_of_edges()}")
# Out:
# Nodes: ['APC', 'CD28', 'TCR', 'BCL6', 'GATA3', 'IFNG', 'IFNG_2', 'IL21', 'RORGT', 'TBET', 'TBET_2', 'NFAT', 'CD4', 'RUNX3', 'THPOK', 'CD8', 'CMAF', 'IL10', 'IL13', 'IL22', 'IL4', 'IL5', 'DLL1', 'NOTCH1', 'EOMES', 'GZMB', 'PRF1', 'FOXP3', 'IL17', 'IL2', 'IL2RA', 'IL35', 'NFKB', 'TGFB', 'IL12R', 'IL25', 'IL3', 'ST2', 'STAT4', 'IFNAR', 'STAT1', 'STAT1_2', 'IFNA_e', 'IFNBR', 'IFNB_e', 'IFNGR', 'IFNGR_2', 'IL9', 'STAT6', 'JAK1', 'IFNG_e', 'IKB', 'IL10R', 'STAT3', 'IL10_e', 'IL12RB1_2', 'IL12RB2', 'IL12_e', 'IL18R', 'IL15R', 'STAT5', 'IL15_e', 'IRAK', 'IL18_e', 'IL1R', 'IL1R1', 'IL1_e', 'IL2R', 'IL2R_2', 'IL21R', 'IL21_e', 'IL23', 'IL23R', 'IL23_e', 'IL25R', 'IL25_e', 'IL27R', 'IL27_e', 'IL29R', 'IL29_e', 'STAT5_2', 'IL2_e', 'IL33R', 'IL33_e', 'IL36R', 'IL36_e', 'IL4R', 'IL4R_2', 'IL4RA_2', 'IL4_e', 'IL6', 'IL6R', 'IL6_e', 'IL7R', 'IL7_e', 'IRF1', 'JAK3', 'IL24', 'IL31', 'TGFBR', 'PU1', 'SMAD2', 'SMAD3', 'SOCS1', 'proliferation', 'TGFB_e']
# Edges: [('APC', 'CD28', {'distance': 1}), ('APC', 'TCR', {'distance': 1}), ('CD28', 'NFAT', {'distance': 1}), ('TCR', 'CD8', {'distance': 2}), ('TCR', 'IKB', {'distance': 1}), ('TCR', 'IL12R', {'distance': 2}), ('TCR', 'IL7R', {'distance': 1}), ('TCR', 'NFAT', {'distance': 1}), ('TCR', 'THPOK', {'distance': 2}), ('BCL6', 'GATA3', {'distance': 1}), ('BCL6', 'IFNG', {'distance': 1}), ('BCL6', 'IFNG_2', {'distance': 1}), ('BCL6', 'IL21', {'distance': 1}), ('BCL6', 'RORGT', {'distance': 2}), ('BCL6', 'TBET', {'distance': 1}), ('BCL6', 'TBET_2', {'distance': 1}), ('GATA3', 'FOXP3', {'distance': 2}), ('GATA3', 'GATA3', {'distance': 1}), ('GATA3', 'IFNG', {'distance': 1}), ('GATA3', 'IFNG_2', {'distance': 1}), ('GATA3', 'IL10', {'distance': 2}), ('GATA3', 'IL12R', {'distance': 2}), ('GATA3', 'IL13', {'distance': 1}), ('GATA3', 'IL25', {'distance': 4}), ('GATA3', 'IL3', {'distance': 1}), ('GATA3', 'IL4', {'distance': 1}), ('GATA3', 'IL5', {'distance': 1}), ('GATA3', 'RORGT', {'distance': 1}), ('GATA3', 'ST2', {'distance': 1}), ('GATA3', 'STAT4', {'distance': 1}), ('GATA3', 'TBET', {'distance': 1}), ('GATA3', 'TBET_2', {'distance': 1}), ('GATA3', 'THPOK', {'distance': 1}), ('IFNG', 'GATA3', {'distance': 2}), ('IFNG', 'IFNG', {'distance': 2}), ('IFNG', 'IFNGR', {'distance': 1}), ('IFNG', 'IFNGR_2', {'distance': 1}), ('IFNG', 'IFNG_2', {'distance': 0}), ('IFNG', 'IL10', {'distance': 2}), ('IFNG', 'IL2', {'distance': 2}), ('IFNG', 'IL21', {'distance': 2}), ('IFNG', 'IL4', {'distance': 2}), ('IFNG', 'IL9', {'distance': 2}), ('IFNG', 'STAT6', {'distance': 2}), ('IFNG', 'TBET', {'distance': 2}), ('IFNG', 'TBET_2', {'distance': 2}), ('IFNG_2', 'GATA3', {'distance': 2}), ('IFNG_2', 'IFNGR', {'distance': 1}), ('IFNG_2', 'IFNGR_2', {'distance': 1}), ('IFNG_2', 'IFNG_2', {'distance': 2}), ('IFNG_2', 'IL10', {'distance': 2}), ('IFNG_2', 'IL2', {'distance': 2}), ('IFNG_2', 'IL21', {'distance': 2}), ('IFNG_2', 'IL4', {'distance': 2}), ('IFNG_2', 'IL9', {'distance': 2}), ('IFNG_2', 'STAT6', {'distance': 2}), ('IFNG_2', 'TBET', {'distance': 2}), ('IFNG_2', 'TBET_2', {'distance': 2}), ('IL21', 'BCL6', {'distance': 2}), ('IL21', 'FOXP3', {'distance': 2}), ('IL21', 'GATA3', {'distance': 3}), ('IL21', 'IFNG', {'distance': 3}), ('IL21', 'IFNG_2', {'distance': 3}), ('IL21', 'IL10', {'distance': 2}), ('IL21', 'IL2', {'distance': 2}), ('IL21', 'IL21', {'distance': 2}), ('IL21', 'IL21R', {'distance': 1}), ('IL21', 'IL9', {'distance': 3}), ('IL21', 'RORGT', {'distance': 2}), ('RORGT', 'IL17', {'distance': 1}), ('RORGT', 'IL21', {'distance': 3}), ('RORGT', 'IL23R', {'distance': 1}), ('RORGT', 'RORGT', {'distance': 1}), ('RORGT', 'TBET', {'distance': 3}), ('RORGT', 'TBET_2', {'distance': 3}), ('TBET', 'BCL6', {'distance': 1}), ('TBET', 'FOXP3', {'distance': 1}), ('TBET', 'GATA3', {'distance': 1}), ('TBET', 'IFNG', {'distance': 1}), ('TBET', 'IFNG_2', {'distance': 1}), ('TBET', 'IL12R', {'distance': 2}), ('TBET', 'IL2', {'distance': 1}), ('TBET', 'IL23R', {'distance': 1}), ('TBET', 'IL4', {'distance': 1}), ('TBET', 'RORGT', {'distance': 1}), ('TBET', 'RUNX3', {'distance': 2}), ('TBET', 'TBET', {'distance': 2}), ('TBET', 'TBET_2', {'distance': 0}), ('TBET_2', 'BCL6', {'distance': 1}), ('TBET_2', 'FOXP3', {'distance': 1}), ('TBET_2', 'GATA3', {'distance': 1}), ('TBET_2', 'IFNG', {'distance': 1}), ('TBET_2', 'IFNG_2', {'distance': 1}), ('TBET_2', 'IL12R', {'distance': 2}), ('TBET_2', 'IL2', {'distance': 1}), ('TBET_2', 'IL23R', {'distance': 1}), ('TBET_2', 'IL4', {'distance': 1}), ('TBET_2', 'RORGT', {'distance': 1}), ('TBET_2', 'RUNX3', {'distance': 2}), ('TBET_2', 'TBET_2', {'distance': 2}), ('NFAT', 'FOXP3', {'distance': 1}), ('NFAT', 'GATA3', {'distance': 1}), ('NFAT', 'IFNG', {'distance': 1}), ('NFAT', 'IFNGR', {'distance': 2}), ('NFAT', 'IFNGR_2', {'distance': 2}), ('NFAT', 'IFNG_2', {'distance': 1}), ('NFAT', 'IL10', {'distance': 1}), ('NFAT', 'IL13', {'distance': 1}), ('NFAT', 'IL17', {'distance': 1}), ('NFAT', 'IL2', {'distance': 1}), ('NFAT', 'IL21', {'dist ...
# Number of nodes: 106
# Number of edges: 430

# %%
B = dc.ultrametric_backbone(G, weight='distance', self_loops=False)

# %%
def print_report(graph):
    print(f"Number of nodes: {graph.number_of_nodes()}")
    print(f"Number of edges: {graph.number_of_edges()}")

    max_in_degree = 0
    max_in_degree_node = None
    log2_number_of_possible_BN = 1
    for node in graph.nodes():
        log2_number_of_possible_BN += 2**graph.in_degree(node)

        if graph.in_degree(node) > max_in_degree:
            max_in_degree = graph.in_degree(node)
            max_in_degree_node = node
    print("node with highest in-degree: ", max_in_degree_node, " with in-degree: ", max_in_degree)
    print("number of possible Boolean Networks: 2^", log2_number_of_possible_BN)

# %%
print_report(G)
print()
print_report(B)
# Out:
# Number of nodes: 106
# Number of edges: 430
# node with highest in-degree:  IFNG_2  with in-degree:  23
# number of possible Boolean Networks: 2^ 13840246
#
# Number of nodes: 106
# Number of edges: 286
# node with highest in-degree:  IFNG_2  with in-degree:  14
# number of possible Boolean Networks: 2^ 29446

# %%
edges_G = set((u, v, d.get('distance')) for u, v, d in G.edges(data=True))
edges_B = set((u, v, d.get('distance')) for u, v, d in B.edges(data=True))

missing_from_B = edges_G - edges_B

print("Edges in G but missing or different in B:")
missing_self_edges_from_B = set()
for u, v, w in missing_from_B:
    print(f"Edge ({u} -> {v}) with weight {w}")
    if u == v:
        missing_self_edges_from_B.add((u, v, w))

missing_from_G = edges_B - edges_G

print("Edges in B but missing or different in G:")
for u, v, w in missing_from_G:
    print(f"Edge ({u} -> {v}) with weight {w}")
# Out:
# Edges in G but missing or different in B:
# Edge (TGFB -> IFNG_2) with weight 2
# Edge (NFAT -> IL24) with weight 4
# Edge (IL2 -> IL4) with weight 2
# Edge (TBET_2 -> RUNX3) with weight 2
# Edge (IL4 -> IFNG) with weight 2
# Edge (NFAT -> IL2R_2) with weight 2
# Edge (IL21R -> RORGT) with weight 2
# Edge (RORGT -> TBET_2) with weight 3
# Edge (STAT3 -> IFNG_2) with weight 2
# Edge (TGFB -> IL9) with weight 2
# Edge (RORGT -> TBET) with weight 3
# Edge (IL21 -> FOXP3) with weight 2
# Edge (TGFB_e -> TGFB) with weight 2
# Edge (STAT5 -> IL2) with weight 2
# Edge (GATA3 -> IL10) with weight 2
# Edge (IL27_e -> STAT1) with weight 2
# Edge (IL6R -> RORGT) with weight 2
# Edge (IFNG -> IL21) with weight 2
# Edge (CMAF -> IL5) with weight 2
# Edge (TGFB -> FOXP3) with weight 2
# Edge (TCR -> THPOK) with weight 2
# Edge (TBET -> RUNX3) with weight 2
# Edge (TGFB_e -> GATA3) with weight 2
# Edge (FOXP3 -> IL4) with weight 2
# Edge (FOXP3 -> IL13) with weight 2
# Edge (STAT6 -> IFNG_2) with weight 2
# Edge (IL23R -> IL17) with weight 2
# Edge (STAT3 -> FOXP3) with weight 2
# Edge (IL2 -> GATA3) with weight 2
# Edge (IFNG_e -> IFNG) with weight 2
# Edge (IL2 -> BCL6) with weight 2
# Edge (FOXP3 -> TBET) with weight 4
# Edge (IFNG_2 -> TBET) with weight 2
# Edge (IL21 -> IL2) with weight 2
# Edge (RORGT -> IL21) with weight 3
# Edge (IFNG -> IL4) with weight 2
# Edge (IL12_e -> STAT4) with weight 2
# Edge (GATA3 -> FOXP3) with weight 2
# Edge (CD4 -> RUNX3) with weight 3
# Edge (IL21 -> IL10) with weight 2
# Edge (GATA3 -> IL12R) with weight 2
# Edge (TBET -> TBET) with weight 2
# Edge (STAT1_2 -> IL4) with weight 2
# Edge (TGFB -> IL10) with weight 2
# Edge (IL2_e -> IL2) with weight 2
# Edge (IL12_e -> IL18R) with weight 2
# Edge (IL4 -> TBET) with weight 2
# Edge (STAT1_2 -> FOXP3) with weight 2
# Edge (STAT1 -> IL17) with weight 2
# Edge (TGFBR -> RORGT) with weight 2
# Edge (IL4 -> TBET_2) with weight 2
# Edge (IL10 -> IFNG_2) with weight 2
# Edge (STAT6 -> IL12R) with weight 2
# Edge (CD4 -> CD4) with weight 4
# Edge (IL21 -> GATA3) with weight 3
# Edge (FOXP3 -> IL5) with weight 2
# Edge (STAT6 -> IFNG) with weight 2
# Edge (IFNG -> GATA3) with weight 2
# Edge (IFNG_2 -> IL2) with weight 2
# Edge (GATA3 -> GATA3) with weight 1
# Edge (IL21 -> IL9) with weight 3
# Edge (IL2 -> IL9) with weight 2
# Edge (STAT1 -> STAT1) with weight 1
# Edge (IL21_e -> IL21) with weight 2
# Edge (IFNG_2 -> TBET_2) with weight 2
# Edge (IL27_e -> STAT1_2) with weight 2
# Edge (IL27R -> EOMES) with weight 2
# Edge (IFNG -> IL9) with weight 2
# Edge (TCR -> CD8) with weight 2
# Edge (NFAT -> STAT1) with weight 2
# Edge (STAT3 -> IFNG) with weight 2
# Edge (NFAT -> IL2R) with weight 2
# Edge (IFNG_2 -> IL4) with weight 2
# Edge (IL2 -> FOXP3) with weight 2
# Edge (FOXP3 -> THPOK) with weight 4
# Edge (STAT1_2 -> IL17) with weight 2
# Edge (CD8 -> CD8) with weight 4
# Edge (proliferation -> proliferation) with weight 4
# Edge (IL10 -> IFNG) with weight 2
# Edge (IL21 -> IFNG) with weight 3
# Edge (STAT4 -> IL10) with weight 2
# Edge (FOXP3 -> IFNG_2) with weight 2
# Edge (IL21 -> IFNG_2) with weight 3
# Edge (IFNG_2 -> IL21) with weight 2
# Edge (IFNG -> IFNG) with weight 2
# Edge (CD8 -> THPOK) with weight 3
# Edge (IL10 -> IL2) with weight 2
# Edge (IFNG_2 -> IFNG_2) with weight 2
# Edge (IFNG_2 -> GATA3) with weight 2
# Edge (IL2 -> IL2) with weight 2
# Edge (IL4_e -> IL4) with weight 2
# Edge (TGFB -> TGFB) with weight 2
# Edge (IFNG -> IL2) with weight 2
# Edge (IL21 -> RORGT) with weight 2
# Edge (IFNG_2 -> IL9) with weight 2
# Edge (IFNG -> IL10) with weight 2
# Edge (STAT6 -> IL2) with weight 2
# Edge (IL21 -> IL21) with weight 2
# Edge (IFNG -> TBET_2) with weight 2
# Edge (IL4 -> IL4) with weight 2
# Edge (IFNG_2 -> STAT6) with weight 2
# Edge (IL10 -> IL10) with weight 2
# Edge (TGFBR -> CMAF) with weight 2
# Edge (NFAT -> TGFBR) with weight 2
# Edge (NFAT -> IFNGR) with weight 2
# Edge (TGFB -> RORGT) with weight 2
# Edge (FOXP3 -> FOXP3) with weight 2
# Edge (STAT4 -> IL12R) with weight 2
# Edge (IFNGR -> IFNGR) with weight 2
# Edge (THPOK -> THPOK) with weight 1
# Edge (TCR -> IL12R) with weight 2
# Edge (NFAT -> STAT1_2) with weight 2
# Edge (TGFB -> GATA3) with weight 2
# Edge (IL21 -> BCL6) with weight 2
# Edge (STAT6 -> IL17) with weight 2
# Edge (STAT6 -> IL18R) with weight 2
# Edge (FOXP3 -> IFNG) with weight 2
# Edge (IL6R -> FOXP3) with weight 2
# Edge (IL4 -> IFNG_2) with weight 2
# Edge (BCL6 -> RORGT) with weight 2
# Edge (TGFBR -> FOXP3) with weight 2
# Edge (IL4 -> GATA3) with weight 2
# Edge (IL10 -> IL9) with weight 3
# Edge (STAT1 -> IL4) with weight 2
# Edge (RORGT -> RORGT) with weight 1
# Edge (IL4 -> IL9) with weight 2
# Edge (RUNX3 -> RUNX3) with weight 4
# Edge (TBET_2 -> IL12R) with weight 2
# Edge (CMAF -> IL13) with weight 2
# Edge (NFAT -> IFNGR_2) with weight 2
# Edge (STAT1 -> FOXP3) with weight 2
# Edge (IL2 -> IL21) with weight 2
# Edge (TBET_2 -> TBET_2) with weight 2
# Edge (IFNG -> STAT6) with weight 2
# Edge (FOXP3 -> TGFB) with weight 3
# Edge (IFNG_e -> IFNG_2) with weight 2
# Edge (FOXP3 -> IL17) with weight 2
# Edge (FOXP3 -> TBET_2) with weight 4
# Edge (IFNG -> TBET) with weight 2
# Edge (IL10_e -> IL10) with weight 2
# Edge (TBET -> IL12R) with weight 2
# Edge (IFNG_2 -> IL10) with weight 2
# Edge (TGFB -> IFNG) with weight 2
# Edge (IL21R -> FOXP3) with weight 2
# Edges in B but missing or different in G:

# %%
print("Self edges in G and kept in B:")
for u, v, w in edges_G:
    if u != v:
        continue
    if (u, v, w) in edges_B:
        print(f"Edge ({u} -> {v}) with weight {w}")
        
print("Self edges in G but missing or different in B:")
for u, v, w in missing_self_edges_from_B:
    print(f"Edge ({u} -> {v}) with weight {w}")
# Out:
# Self edges in G and kept in B:
# Self edges in G but missing or different in B:
# Edge (FOXP3 -> FOXP3) with weight 2
# Edge (IFNGR -> IFNGR) with weight 2
# Edge (THPOK -> THPOK) with weight 1
# Edge (TBET -> TBET) with weight 2
# Edge (CD8 -> CD8) with weight 4
# Edge (proliferation -> proliferation) with weight 4
# Edge (RORGT -> RORGT) with weight 1
# Edge (RUNX3 -> RUNX3) with weight 4
# Edge (IFNG -> IFNG) with weight 2
# Edge (IFNG_2 -> IFNG_2) with weight 2
# Edge (CD4 -> CD4) with weight 4
# Edge (IL2 -> IL2) with weight 2
# Edge (TBET_2 -> TBET_2) with weight 2
# Edge (TGFB -> TGFB) with weight 2
# Edge (GATA3 -> GATA3) with weight 1
# Edge (IL21 -> IL21) with weight 2
# Edge (STAT1 -> STAT1) with weight 1
# Edge (IL4 -> IL4) with weight 2
# Edge (IL10 -> IL10) with weight 2

# %%
target_nodes = [
    n for n in set(list(G.nodes()) + list(B.nodes()))
    if G.has_edge(n, n) or B.has_edge(n, n)
]

print(f"{len(target_nodes)} target nodes:", target_nodes)
# Out:
# 19 target nodes: ['THPOK', 'IFNG_2', 'GATA3', 'CD8', 'IL21', 'RORGT', 'RUNX3', 'IFNGR', 'proliferation', 'FOXP3', 'IL2', 'TGFB', 'IL10', 'IFNG', 'CD4', 'TBET', 'STAT1', 'TBET_2', 'IL4']

# %%
# --- Helper to process bottleneck cycles per graph ---
def get_bottleneck_cycles(graph, target_nodes):
    # Storage format: { target_node: { neighbor: (path_tuple, max_weight) } }
    results = {}
    
    for node in target_nodes:
        if node not in graph:
            continue
        results[node] = {}
        
        # 1. Capture standalone self-loops directly
        if graph.has_edge(node, node):
            results[node][node] = ((node, node), graph[node][node].get('distance'))
            
        # 2. Use your Dijkstra function to find the minimax return path from successors
        for neighbor in graph.successors(node):
            if neighbor == node:
                continue
                
            paths = {neighbor: [neighbor]}
            weight_fn = lambda v, u, e: e.get('distance')
            
            try:
                # Find the path that minimizes the maximum edge weight back to 'node'
                dist = single_source_dijkstra_path_length(
                    graph, 
                    source=neighbor, 
                    weight_function=weight_fn, 
                    paths=paths, 
                    disjunction=max
                )
                
                # If the target node was reached, a valid optimal bottleneck cycle exists
                if node in dist:
                    path_back = paths[node]
                    full_cycle = [node] + path_back
                    
                    # Total bottleneck is the max of the exit edge and the path back
                    exit_edge_w = graph[node][neighbor].get('distance')
                    cycle_max_w = max(exit_edge_w, dist[node])
                    
                    results[node][neighbor] = (tuple(full_cycle), cycle_max_w)
            except (nx.NodeNotFound, ValueError):
                continue
                
    return results

# %%
# Storage format: { target_node: { neighbor: (path_tuple, max_weight) } }
cycles_G = get_bottleneck_cycles(G, target_nodes)
cycles_B = get_bottleneck_cycles(B, target_nodes)

# %%
def print_discrepancies(cycles_G, cycles_B, target_nodes):
    # Print the discrepancies and matches
    print("--- FAST BOTTLENECK CYCLE ANALYSIS REPORT --- \n")
    for node in target_nodes:
        print(f"=== Node with self-loop: '{node}' ===")
        g_routes = cycles_G.get(node, {})
        b_routes = cycles_B.get(node, {})
        
        # Union of all directional paths attempted through outward neighbors
        all_neighbors = set(g_routes.keys()) | set(b_routes.keys())
        
        for neighbor in all_neighbors:
            in_G = neighbor in g_routes
            in_B = neighbor in b_routes
            
            # Handle self loop comparison
            if neighbor == node:
                if in_G and in_B:
                    w_G = g_routes[node][1]
                    w_B = b_routes[node][1]
                    if w_G == w_B:
                        print(f"  ✅ Self-Loop Match -> Exists in both with identical Max W: {w_G}")
                    else:
                        print(f" ** Self-Loop Mismatch -> G Max W: {w_G} | B Max W: {w_B}")
                elif in_G:
                    print(f" ** Self-Loop unique to G -> (Max W: {g_routes[node][1]})")
                elif in_B:
                    print(f"  ⚠️ Self-Loop unique to B -> (Max W: {b_routes[node][1]})")
                continue
                
            # Handle multi-node cycle comparisons
            if in_G and not in_B:
                path, w = g_routes[neighbor]
                print(f"  * Cycle via '{neighbor}' exists in G but missing in B (G Max W: {w})")
            elif in_B and not in_G:
                path, w = b_routes[neighbor]
                print(f"  * Cycle via '{neighbor}' exists in B but missing in G (B Max W: {w})")
            else:
                path_G, w_G = g_routes[neighbor]
                path_B, w_B = b_routes[neighbor]
                
                # Check if they are completely identical in structure and bottleneck weight
                if w_G == w_B and path_G == path_B:
                    print(f"  ✅ Complete Cycle Match via neighbor '{neighbor}':")
                    print(f"    - Path: {' -> '.join(path_G)} (Identical Max W: {w_G})")
                else:
                    print(f"  ⚠️ Route Discrepancy via neighbor '{neighbor}':")
                    print(f"    - G Path: {' -> '.join(path_G)} (Max W: {w_G})")
                    print(f"    - B Path: {' -> '.join(path_B)} (Max W: {w_B})")
                    
        print("-" * 50)

# %%
print_discrepancies(cycles_G, cycles_B, target_nodes)
# Out:
# --- FAST BOTTLENECK CYCLE ANALYSIS REPORT ---
#
# === Node with self-loop: 'THPOK' ===
#   ✅ Complete Cycle Match via neighbor 'CD4':
#     - Path: THPOK -> CD4 -> THPOK (Identical Max W: 2)
#   ✅ Complete Cycle Match via neighbor 'RUNX3':
#     - Path: THPOK -> RUNX3 -> THPOK (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'CD8':
#     - Path: THPOK -> CD8 -> RUNX3 -> THPOK (Identical Max W: 2)
#  ** Self-Loop unique to G -> (Max W: 1)
# --------------------------------------------------
# === Node with self-loop: 'IFNG_2' ===
#   * Cycle via 'TBET' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'IL10' exists in G but missing in B (G Max W: 2)
#  ** Self-Loop unique to G -> (Max W: 2)
#   * Cycle via 'IL2' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'IL9' exists in G but missing in B (G Max W: 3)
#   * Cycle via 'IL4' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'TBET_2' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'GATA3' exists in G but missing in B (G Max W: 2)
#   ✅ Complete Cycle Match via neighbor 'IFNGR':
#     - Path: IFNG_2 -> IFNGR -> STAT1 -> BCL6 -> IFNG_2 (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'IFNGR_2':
#     - Path: IFNG_2 -> IFNGR_2 -> STAT1 -> BCL6 -> IFNG_2 (Identical Max W: 1)
#   * Cycle via 'IL21' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'STAT6' exists in G but missing in B (G Max W: 2)
# --------------------------------------------------
# === Node with self-loop: 'GATA3' ===
#   ✅ Complete Cycle Match via neighbor 'TBET':
#     - Path: GATA3 -> TBET -> GATA3 (Identical Max W: 1)
#   * Cycle via 'IL10' exists in G but missing in B (G Max W: 2)
#   ✅ Complete Cycle Match via neighbor 'IFNG_2':
#     - Path: GATA3 -> IFNG_2 -> IFNGR -> STAT1 -> BCL6 -> GATA3 (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'IFNG':
#     - Path: GATA3 -> IFNG -> IFNGR -> STAT1 -> BCL6 -> GATA3 (Identical Max W: 1)
#   ⚠️ Route Discrepancy via neighbor 'ST2':
#     - G Path: GATA3 -> ST2 -> IL33R -> IL9 -> IFNG -> GATA3 (Max W: 3)
#     - B Path: GATA3 -> ST2 -> IL33R -> IL9 -> TBET -> GATA3 (Max W: 3)
#   ✅ Complete Cycle Match via neighbor 'TBET_2':
#     - Path: GATA3 -> TBET_2 -> GATA3 (Identical Max W: 1)
#   * Cycle via 'IL12R' exists in G but missing in B (G Max W: 2)
#   ✅ Complete Cycle Match via neighbor 'RORGT':
#     - Path: GATA3 -> RORGT -> IL23R -> STAT3 -> BCL6 -> GATA3 (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'IL25':
#     - Path: GATA3 -> IL25 -> IL25R -> GATA3 (Identical Max W: 4)
#   ✅ Complete Cycle Match via neighbor 'STAT4':
#     - Path: GATA3 -> STAT4 -> BCL6 -> GATA3 (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'IL4':
#     - Path: GATA3 -> IL4 -> IL4R -> STAT5 -> GATA3 (Identical Max W: 1)
#  ** Self-Loop unique to G -> (Max W: 1)
#   * Cycle via 'FOXP3' exists in G but missing in B (G Max W: 2)
#   ✅ Complete Cycle Match via neighbor 'THPOK':
#     - Path: GATA3 -> THPOK -> RUNX3 -> IL4 -> IL4R -> STAT5 -> GATA3 (Identical Max W: 1)
# --------------------------------------------------
# === Node with self-loop: 'CD8' ===
#   ✅ Complete Cycle Match via neighbor 'RUNX3':
#     - Path: CD8 -> RUNX3 -> CD8 (Identical Max W: 2)
#  ** Self-Loop unique to G -> (Max W: 4)
#   * Cycle via 'THPOK' exists in G but missing in B (G Max W: 3)
# --------------------------------------------------
# === Node with self-loop: 'IL21' ===
#   * Cycle via 'BCL6' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'IFNG' exists in G but missing in B (G Max W: 3)
#   * Cycle via 'IFNG_2' exists in G but missing in B (G Max W: 3)
#   * Cycle via 'IL10' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'IL2' exists in G but missing in B (G Max W: 2)
#   ✅ Complete Cycle Match via neighbor 'IL21R':
#     - Path: IL21 -> IL21R -> STAT3 -> IL21 (Identical Max W: 1)
#   * Cycle via 'IL9' exists in G but missing in B (G Max W: 3)
#   * Cycle via 'GATA3' exists in G but missing in B (G Max W: 3)
#   * Cycle via 'RORGT' exists in G but missing in B (G Max W: 2)
#  ** Self-Loop unique to G -> (Max W: 2)
#   * Cycle via 'FOXP3' exists in G but missing in B (G Max W: 2)
# --------------------------------------------------
# === Node with self-loop: 'RORGT' ===
#   * Cycle via 'TBET' exists in G but missing in B (G Max W: 3)
#   * Cycle via 'TBET_2' exists in G but missing in B (G Max W: 3)
#  ** Self-Loop unique to G -> (Max W: 1)
#   * Cycle via 'IL21' exists in G but missing in B (G Max W: 3)
#   ✅ Complete Cycle Match via neighbor 'IL23R':
#     - Path: RORGT -> IL23R -> STAT3 -> RORGT (Identical Max W: 1)
# --------------------------------------------------
# === Node with self-loop: 'RUNX3' ===
#   ✅ Complete Cycle Match via neighbor 'IFNG':
#     - Path: RUNX3 -> IFNG -> IFNGR -> STAT1 -> SOCS1 -> STAT5 -> RUNX3 (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'IFNG_2':
#     - Path: RUNX3 -> IFNG_2 -> IFNGR -> STAT1 -> SOCS1 -> STAT5 -> RUNX3 (Identical Max W: 1)
#  ** Self-Loop unique to G -> (Max W: 4)
#   ✅ Complete Cycle Match via neighbor 'CD8':
#     - Path: RUNX3 -> CD8 -> RUNX3 (Identical Max W: 2)
#   ✅ Complete Cycle Match via neighbor 'IL4':
#     - Path: RUNX3 -> IL4 -> IL4R -> STAT5 -> RUNX3 (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'CD4':
#     - Path: RUNX3 -> CD4 -> THPOK -> RUNX3 (Identical Max W: 2)
#   ✅ Complete Cycle Match via neighbor 'EOMES':
#     - Path: RUNX3 -> EOMES -> IFNG -> IFNGR -> STAT1 -> SOCS1 -> STAT5 -> RUNX3 (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'THPOK':
#     - Path: RUNX3 -> THPOK -> RUNX3 (Identical Max W: 1)
# --------------------------------------------------
# === Node with self-loop: 'IFNGR' ===
#   ✅ Complete Cycle Match via neighbor 'JAK1':
#     - Path: IFNGR -> JAK1 -> STAT1 -> BCL6 -> IFNG -> IFNGR (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'STAT1_2':
#     - Path: IFNGR -> STAT1_2 -> BCL6 -> IFNG -> IFNGR (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'STAT1':
#     - Path: IFNGR -> STAT1 -> BCL6 -> IFNG -> IFNGR (Identical Max W: 1)
#  ** Self-Loop unique to G -> (Max W: 2)
#   ✅ Complete Cycle Match via neighbor 'IFNGR_2':
#     - Path: IFNGR -> IFNGR_2 -> STAT1 -> BCL6 -> IFNG -> IFNGR (Identical Max W: 1)
# --------------------------------------------------
# === Node with self-loop: 'proliferation' ===
#   ✅ Complete Cycle Match via neighbor 'IL10':
#     - Path: proliferation -> IL10 -> IL10R -> STAT3 -> CMAF -> IL4 -> IL4R -> STAT5 -> proliferation (Identical Max W: 4)
#   ✅ Complete Cycle Match via neighbor 'IFNG_2':
#     - Path: proliferation -> IFNG_2 -> IFNGR -> STAT1 -> SOCS1 -> STAT5 -> proliferation (Identical Max W: 4)
#   ✅ Complete Cycle Match via neighbor 'IFNG':
#     - Path: proliferation -> IFNG -> IFNGR -> STAT1 -> SOCS1 -> STAT5 -> proliferation (Identical Max W: 4)
#   ✅ Complete Cycle Match via neighbor 'IL6':
#     - Path: proliferation -> IL6 -> IL6R -> STAT3 -> CMAF -> IL4 -> IL4R -> STAT5 -> proliferation (Identical Max W: 4)
#   ✅ Complete Cycle Match via neighbor 'TGFB':
#     - Path: proliferation -> TGFB -> BCL6 -> GATA3 -> IL4 -> IL4R -> STAT5 -> proliferation (Identical Max W: 4)
#   ✅ Complete Cycle Match via neighbor 'IL25':
#     - Path: proliferation -> IL25 -> IL25R -> GATA3 -> IL4 -> IL4R -> STAT5 -> proliferation (Identical Max W: 4)
#   ⚠️ Route Discrepancy via neighbor 'IL9':
#     - G Path: proliferation -> IL9 -> IFNG -> IL2 -> IL2R -> STAT5 -> proliferation (Max W: 4)
#     - B Path: proliferation -> IL9 -> TBET -> IL2 -> IL2R -> STAT5 -> proliferation (Max W: 4)
#   ✅ Complete Cycle Match via neighbor 'IL4':
#     - Path: proliferation -> IL4 -> IL4R -> STAT5 -> proliferation (Identical Max W: 4)
#  ** Self-Loop unique to G -> (Max W: 4)
#   ✅ Complete Cycle Match via neighbor 'IL23':
#     - Path: proliferation -> IL23 -> IL23R -> STAT3 -> CMAF -> IL4 -> IL4R -> STAT5 -> proliferation (Identical Max W: 4)
#   ✅ Complete Cycle Match via neighbor 'IL21':
#     - Path: proliferation -> IL21 -> IL21R -> STAT3 -> CMAF -> IL4 -> IL4R -> STAT5 -> proliferation (Identical Max W: 4)
# --------------------------------------------------
# === Node with self-loop: 'FOXP3' ===
#   * Cycle via 'TBET' exists in G but missing in B (G Max W: 4)
#   * Cycle via 'IFNG_2' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'IFNG' exists in G but missing in B (G Max W: 2)
#   ✅ Complete Cycle Match via neighbor 'NFKB':
#     - Path: FOXP3 -> NFKB -> IL2 -> IL2R -> STAT5 -> FOXP3 (Identical Max W: 1)
#   * Cycle via 'TBET_2' exists in G but missing in B (G Max W: 4)
#   ✅ Complete Cycle Match via neighbor 'RORGT':
#     - Path: FOXP3 -> RORGT -> IL23R -> STAT3 -> BCL6 -> TBET -> FOXP3 (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'IL2RA':
#     - Path: FOXP3 -> IL2RA -> IL2R_2 -> STAT5 -> FOXP3 (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'IL2':
#     - Path: FOXP3 -> IL2 -> IL2R -> STAT5 -> FOXP3 (Identical Max W: 1)
#   * Cycle via 'IL4' exists in G but missing in B (G Max W: 2)
#   ✅ Complete Cycle Match via neighbor 'GATA3':
#     - Path: FOXP3 -> GATA3 -> TBET -> FOXP3 (Identical Max W: 1)
#   * Cycle via 'TGFB' exists in G but missing in B (G Max W: 3)
#   ✅ Complete Cycle Match via neighbor 'NFAT':
#     - Path: FOXP3 -> NFAT -> FOXP3 (Identical Max W: 1)
#  ** Self-Loop unique to G -> (Max W: 2)
#   * Cycle via 'THPOK' exists in G but missing in B (G Max W: 4)
# --------------------------------------------------
# === Node with self-loop: 'IL2' ===
#   * Cycle via 'BCL6' exists in G but missing in B (G Max W: 2)
#  ** Self-Loop unique to G -> (Max W: 2)
#   * Cycle via 'IL9' exists in G but missing in B (G Max W: 3)
#   ✅ Complete Cycle Match via neighbor 'IL2R_2':
#     - Path: IL2 -> IL2R_2 -> STAT5 -> FOXP3 -> IL2 (Identical Max W: 1)
#   * Cycle via 'IL4' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'GATA3' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'IL21' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'FOXP3' exists in G but missing in B (G Max W: 2)
#   ✅ Complete Cycle Match via neighbor 'IL2R':
#     - Path: IL2 -> IL2R -> STAT5 -> FOXP3 -> IL2 (Identical Max W: 1)
# --------------------------------------------------
# === Node with self-loop: 'TGFB' ===
#   ✅ Complete Cycle Match via neighbor 'BCL6':
#     - Path: TGFB -> BCL6 -> TBET -> FOXP3 -> NFAT -> TGFB (Identical Max W: 1)
#   * Cycle via 'IFNG' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'IFNG_2' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'IL10' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'IL9' exists in G but missing in B (G Max W: 3)
#   ✅ Complete Cycle Match via neighbor 'TGFBR':
#     - Path: TGFB -> TGFBR -> SMAD2 -> FOXP3 -> NFAT -> TGFB (Identical Max W: 1)
#   * Cycle via 'GATA3' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'RORGT' exists in G but missing in B (G Max W: 2)
#  ** Self-Loop unique to G -> (Max W: 2)
#   * Cycle via 'FOXP3' exists in G but missing in B (G Max W: 2)
# --------------------------------------------------
# === Node with self-loop: 'IL10' ===
#  ** Self-Loop unique to G -> (Max W: 2)
#   * Cycle via 'IFNG_2' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'IFNG' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'IL2' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'IL9' exists in G but missing in B (G Max W: 3)
#   ✅ Complete Cycle Match via neighbor 'IL10R':
#     - Path: IL10 -> IL10R -> STAT3 -> IL10 (Identical Max W: 1)
# --------------------------------------------------
# === Node with self-loop: 'IFNG' ===
#   * Cycle via 'TBET' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'IL10' exists in G but missing in B (G Max W: 2)
#   ✅ Complete Cycle Match via neighbor 'IFNG_2':
#     - Path: IFNG -> IFNG_2 -> IFNGR -> STAT1 -> BCL6 -> IFNG (Identical Max W: 1)
#  ** Self-Loop unique to G -> (Max W: 2)
#   * Cycle via 'IL2' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'IL9' exists in G but missing in B (G Max W: 3)
#   * Cycle via 'IL4' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'TBET_2' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'GATA3' exists in G but missing in B (G Max W: 2)
#   ✅ Complete Cycle Match via neighbor 'IFNGR':
#     - Path: IFNG -> IFNGR -> STAT1 -> BCL6 -> IFNG (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'IFNGR_2':
#     - Path: IFNG -> IFNGR_2 -> STAT1 -> BCL6 -> IFNG (Identical Max W: 1)
#   * Cycle via 'IL21' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'STAT6' exists in G but missing in B (G Max W: 2)
# --------------------------------------------------
# === Node with self-loop: 'CD4' ===
#   * Cycle via 'RUNX3' exists in G but missing in B (G Max W: 3)
#  ** Self-Loop unique to G -> (Max W: 4)
#   ✅ Complete Cycle Match via neighbor 'THPOK':
#     - Path: CD4 -> THPOK -> CD4 (Identical Max W: 2)
# --------------------------------------------------
# === Node with self-loop: 'TBET' ===
#  ** Self-Loop unique to G -> (Max W: 2)
#   ✅ Complete Cycle Match via neighbor 'IFNG':
#     - Path: TBET -> IFNG -> IFNGR -> STAT1 -> TBET (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'IFNG_2':
#     - Path: TBET -> IFNG_2 -> IFNGR -> STAT1 -> TBET (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'TBET_2':
#     - Path: TBET -> TBET_2 -> BCL6 -> TBET (Identical Max W: 1)
#   * Cycle via 'IL12R' exists in G but missing in B (G Max W: 2)
#   ✅ Complete Cycle Match via neighbor 'RORGT':
#     - Path: TBET -> RORGT -> IL23R -> STAT3 -> BCL6 -> TBET (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'BCL6':
#     - Path: TBET -> BCL6 -> TBET (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'IL2':
#     - Path: TBET -> IL2 -> IL2R -> STAT5 -> BCL6 -> TBET (Identical Max W: 1)
#   * Cycle via 'RUNX3' exists in G but missing in B (G Max W: 2)
#   ✅ Complete Cycle Match via neighbor 'IL4':
#     - Path: TBET -> IL4 -> IL4R -> STAT5 -> BCL6 -> TBET (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'IL23R':
#     - Path: TBET -> IL23R -> STAT3 -> BCL6 -> TBET (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'GATA3':
#     - Path: TBET -> GATA3 -> TBET (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'FOXP3':
#     - Path: TBET -> FOXP3 -> GATA3 -> TBET (Identical Max W: 1)
# --------------------------------------------------
# === Node with self-loop: 'STAT1' ===
#   ✅ Complete Cycle Match via neighbor 'IRF1':
#     - Path: STAT1 -> IRF1 -> IL12RB1_2 -> IL12R -> STAT4 -> IFNG -> IFNGR -> STAT1 (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'TBET':
#     - Path: STAT1 -> TBET -> IFNG -> IFNGR -> STAT1 (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'SOCS1':
#     - Path: STAT1 -> SOCS1 -> JAK1 -> STAT1 (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'BCL6':
#     - Path: STAT1 -> BCL6 -> IFNG -> IFNGR -> STAT1 (Identical Max W: 1)
#   * Cycle via 'IL4' exists in G but missing in B (G Max W: 2)
#   ✅ Complete Cycle Match via neighbor 'STAT1_2':
#     - Path: STAT1 -> STAT1_2 -> SOCS1 -> JAK1 -> STAT1 (Identical Max W: 1)
#  ** Self-Loop unique to G -> (Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'TBET_2':
#     - Path: STAT1 -> TBET_2 -> IFNG -> IFNGR -> STAT1 (Identical Max W: 1)
#   * Cycle via 'FOXP3' exists in G but missing in B (G Max W: 2)
# --------------------------------------------------
# === Node with self-loop: 'TBET_2' ===
#   ✅ Complete Cycle Match via neighbor 'IFNG':
#     - Path: TBET_2 -> IFNG -> IFNGR -> STAT1 -> TBET_2 (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'IFNG_2':
#     - Path: TBET_2 -> IFNG_2 -> IFNGR -> STAT1 -> TBET_2 (Identical Max W: 1)
#  ** Self-Loop unique to G -> (Max W: 2)
#   * Cycle via 'IL12R' exists in G but missing in B (G Max W: 2)
#   ✅ Complete Cycle Match via neighbor 'RORGT':
#     - Path: TBET_2 -> RORGT -> IL23R -> STAT3 -> BCL6 -> TBET_2 (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'BCL6':
#     - Path: TBET_2 -> BCL6 -> TBET_2 (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'IL2':
#     - Path: TBET_2 -> IL2 -> IL2R -> STAT5 -> BCL6 -> TBET_2 (Identical Max W: 1)
#   * Cycle via 'RUNX3' exists in G but missing in B (G Max W: 2)
#   ✅ Complete Cycle Match via neighbor 'IL4':
#     - Path: TBET_2 -> IL4 -> IL4R -> STAT5 -> BCL6 -> TBET_2 (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'IL23R':
#     - Path: TBET_2 -> IL23R -> STAT3 -> BCL6 -> TBET_2 (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'GATA3':
#     - Path: TBET_2 -> GATA3 -> TBET_2 (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'FOXP3':
#     - Path: TBET_2 -> FOXP3 -> GATA3 -> TBET_2 (Identical Max W: 1)
# --------------------------------------------------
# === Node with self-loop: 'IL4' ===
#   * Cycle via 'TBET' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'IFNG_2' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'IFNG' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'IL9' exists in G but missing in B (G Max W: 3)
#   ✅ Complete Cycle Match via neighbor 'IL4R_2':
#     - Path: IL4 -> IL4R_2 -> STAT5_2 -> GATA3 -> IL4 (Identical Max W: 1)
#  ** Self-Loop unique to G -> (Max W: 2)
#   ✅ Complete Cycle Match via neighbor 'IL4R':
#     - Path: IL4 -> IL4R -> STAT5 -> IL4 (Identical Max W: 1)
#   * Cycle via 'TBET_2' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'GATA3' exists in G but missing in B (G Max W: 2)
# --------------------------------------------------

# %%
def find_missing_self_edges(G, B, cycles_G, cycles_B):
    """
    Validates structural rules between G and B. Identifies and returns 
    self-edges that need to be restored to B based on the loop weights.
    
    Returns:
    --------
    list of tuples: [(node, node, edge_attributes_dict), ...]
    """
    self_edges_to_restore = []
    
    all_nodes_with_self_loops = {
        n for n in set(list(G.nodes()) + list(B.nodes())) 
        if G.has_edge(n, n) or B.has_edge(n, n)
    }

    for node in all_nodes_with_self_loops:
        has_self_G = G.has_edge(node, node)
        has_self_B = B.has_edge(node, node)
        
        # 1: Subset violation: Self-loop exists in B but missing in G
        if has_self_B and not has_self_G:
            raise ValueError(f"CRITICAL ERROR: Self-loop exists in B but missing in G at Node '{node}'!")
        if has_self_B and G[node][node].get('distance') != B[node][node].get('distance'):
            raise ValueError(f"CRITICAL ERROR: Self-loop weight in B disagrees with G at Node '{node}'!")
        
        g_routes = cycles_G.get(node, {})
        b_routes = cycles_B.get(node, {})
        
        # Isolate multi-node cycles (excluding the self-loop edge itself)
        multi_node_cycles_G = {neigh: (path, w) for neigh, (path, w) in g_routes.items() if neigh != node}
        multi_node_cycles_B = {neigh: (path, w) for neigh, (path, w) in b_routes.items() if neigh != node}

        # 2: Subset violation: Cycle exists in B but missing or different in G
        for neighbor, b_data in multi_node_cycles_B.items():
            if multi_node_cycles_G.get(neighbor)[1] != b_data[1]:
                raise ValueError(f"CRITICAL ERROR: Cycle via '{neighbor}' in B disagrees with or is missing in G at Node '{node}'!")
        
        # Safe Check: Skip if node contains no multi-node pathways to calculate min() over
        if not multi_node_cycles_G:
            continue
            
        # Find the loop(s) in G that have the absolute smallest max-weight
        min_weight_in_G = min(w for path, w in multi_node_cycles_G.values())
        smallest_loops_G = [neigh for neigh, (path, w) in multi_node_cycles_G.items() if w == min_weight_in_G]
        
        for neighbor in smallest_loops_G:
            path_G, w_G = multi_node_cycles_G[neighbor]
            
            # 3. Error: The optimal path disappeared from B or changed
            if multi_node_cycles_G[neighbor][1] != multi_node_cycles_B.get(neighbor)[1]:
                raise KeyError(f"CRITICAL ERROR: Smallest loop via '{neighbor}' in G disagrees with or is missing in B at Node '{node}'!")
                
            # 4. Target Check: Loop weight >= self-loop weight
            # Meaning this self-edge should NOT have been deleted from B.
            self_weight_G = G[node][node].get('distance')
            if w_G >= self_weight_G:
                # Package up the edge configuration details to return
                if not has_self_B:
                    self_edges_to_restore.append((node, node, G[node][node]))
                    print(f"📍 Target Found at Node '{node}': Loop via '{neighbor}' (W: {w_G}) >= Self-Loop (W: {self_weight_G})")
                    break # Found the anomaly for this node, skip to next node
                
    return self_edges_to_restore

# %%
# Collection list to track self-edges that need to be re-added to B
self_edges_to_restore = find_missing_self_edges(G, B, cycles_G, cycles_B)
# Out:
# 📍 Target Found at Node 'proliferation': Loop via 'IFNG' (W: 4) >= Self-Loop (W: 4)
# 📍 Target Found at Node 'THPOK': Loop via 'RUNX3' (W: 1) >= Self-Loop (W: 1)
# 📍 Target Found at Node 'STAT1': Loop via 'BCL6' (W: 1) >= Self-Loop (W: 1)
# 📍 Target Found at Node 'RORGT': Loop via 'IL23R' (W: 1) >= Self-Loop (W: 1)
# 📍 Target Found at Node 'GATA3': Loop via 'IFNG' (W: 1) >= Self-Loop (W: 1)

# %%
print("\n--- PHASE 2: RESTORING EDGES TO B ---")

if self_edges_to_restore:
    print(f"Adding {len(self_edges_to_restore)} self-edges back into Graph B...")
    B2 = B.copy()
    B2.add_edges_from(self_edges_to_restore)
    
    # Recalculate bottleneck paths for B now that it has been altered
    cycles_B_updated = get_bottleneck_cycles(B2, target_nodes)
    
    new_edges_to_restore = find_missing_self_edges(G, B2, cycles_G, cycles_B_updated)
    
    if new_edges_to_restore:
        print(f"More self-edges to restore: {len(new_edges_to_restore)}")

    else:
        print("No more self-edges to restore.")
else:
    print("No target nodes triggered the condition. Graph B remains unchanged.")
# Out:
# --- PHASE 2: RESTORING EDGES TO B ---
# Adding 5 self-edges back into Graph B...
# No more self-edges to restore.

# %%
print_discrepancies(cycles_G, cycles_B_updated, target_nodes)
# Out:
# --- FAST BOTTLENECK CYCLE ANALYSIS REPORT ---
#
# === Node with self-loop: 'THPOK' ===
#   ✅ Complete Cycle Match via neighbor 'RUNX3':
#     - Path: THPOK -> RUNX3 -> THPOK (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'CD8':
#     - Path: THPOK -> CD8 -> RUNX3 -> THPOK (Identical Max W: 2)
#   ✅ Complete Cycle Match via neighbor 'CD4':
#     - Path: THPOK -> CD4 -> THPOK (Identical Max W: 2)
#   ✅ Self-Loop Match -> Exists in both with identical Max W: 1
# --------------------------------------------------
# === Node with self-loop: 'IFNG_2' ===
#   * Cycle via 'TBET' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'IL10' exists in G but missing in B (G Max W: 2)
#  ** Self-Loop unique to G -> (Max W: 2)
#   * Cycle via 'IL2' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'IL9' exists in G but missing in B (G Max W: 3)
#   * Cycle via 'IL4' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'TBET_2' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'GATA3' exists in G but missing in B (G Max W: 2)
#   ✅ Complete Cycle Match via neighbor 'IFNGR':
#     - Path: IFNG_2 -> IFNGR -> STAT1 -> BCL6 -> IFNG_2 (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'IFNGR_2':
#     - Path: IFNG_2 -> IFNGR_2 -> STAT1 -> BCL6 -> IFNG_2 (Identical Max W: 1)
#   * Cycle via 'IL21' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'STAT6' exists in G but missing in B (G Max W: 2)
# --------------------------------------------------
# === Node with self-loop: 'GATA3' ===
#   ✅ Complete Cycle Match via neighbor 'TBET':
#     - Path: GATA3 -> TBET -> GATA3 (Identical Max W: 1)
#   * Cycle via 'IL10' exists in G but missing in B (G Max W: 2)
#   ✅ Complete Cycle Match via neighbor 'IFNG_2':
#     - Path: GATA3 -> IFNG_2 -> IFNGR -> STAT1 -> BCL6 -> GATA3 (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'IFNG':
#     - Path: GATA3 -> IFNG -> IFNGR -> STAT1 -> BCL6 -> GATA3 (Identical Max W: 1)
#   ⚠️ Route Discrepancy via neighbor 'ST2':
#     - G Path: GATA3 -> ST2 -> IL33R -> IL9 -> IFNG -> GATA3 (Max W: 3)
#     - B Path: GATA3 -> ST2 -> IL33R -> IL9 -> TBET -> GATA3 (Max W: 3)
#   ✅ Complete Cycle Match via neighbor 'TBET_2':
#     - Path: GATA3 -> TBET_2 -> GATA3 (Identical Max W: 1)
#   * Cycle via 'IL12R' exists in G but missing in B (G Max W: 2)
#   ✅ Complete Cycle Match via neighbor 'RORGT':
#     - Path: GATA3 -> RORGT -> IL23R -> STAT3 -> BCL6 -> GATA3 (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'IL25':
#     - Path: GATA3 -> IL25 -> IL25R -> GATA3 (Identical Max W: 4)
#   ✅ Complete Cycle Match via neighbor 'STAT4':
#     - Path: GATA3 -> STAT4 -> BCL6 -> GATA3 (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'IL4':
#     - Path: GATA3 -> IL4 -> IL4R -> STAT5 -> GATA3 (Identical Max W: 1)
#   ✅ Self-Loop Match -> Exists in both with identical Max W: 1
#   * Cycle via 'FOXP3' exists in G but missing in B (G Max W: 2)
#   ✅ Complete Cycle Match via neighbor 'THPOK':
#     - Path: GATA3 -> THPOK -> RUNX3 -> IL4 -> IL4R -> STAT5 -> GATA3 (Identical Max W: 1)
# --------------------------------------------------
# === Node with self-loop: 'CD8' ===
#   ✅ Complete Cycle Match via neighbor 'RUNX3':
#     - Path: CD8 -> RUNX3 -> CD8 (Identical Max W: 2)
#  ** Self-Loop unique to G -> (Max W: 4)
#   * Cycle via 'THPOK' exists in G but missing in B (G Max W: 3)
# --------------------------------------------------
# === Node with self-loop: 'IL21' ===
#   * Cycle via 'BCL6' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'IFNG' exists in G but missing in B (G Max W: 3)
#   * Cycle via 'IFNG_2' exists in G but missing in B (G Max W: 3)
#   * Cycle via 'IL10' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'IL2' exists in G but missing in B (G Max W: 2)
#   ✅ Complete Cycle Match via neighbor 'IL21R':
#     - Path: IL21 -> IL21R -> STAT3 -> IL21 (Identical Max W: 1)
#   * Cycle via 'IL9' exists in G but missing in B (G Max W: 3)
#   * Cycle via 'GATA3' exists in G but missing in B (G Max W: 3)
#   * Cycle via 'RORGT' exists in G but missing in B (G Max W: 2)
#  ** Self-Loop unique to G -> (Max W: 2)
#   * Cycle via 'FOXP3' exists in G but missing in B (G Max W: 2)
# --------------------------------------------------
# === Node with self-loop: 'RORGT' ===
#   * Cycle via 'TBET' exists in G but missing in B (G Max W: 3)
#   * Cycle via 'TBET_2' exists in G but missing in B (G Max W: 3)
#   ✅ Self-Loop Match -> Exists in both with identical Max W: 1
#   * Cycle via 'IL21' exists in G but missing in B (G Max W: 3)
#   ✅ Complete Cycle Match via neighbor 'IL23R':
#     - Path: RORGT -> IL23R -> STAT3 -> RORGT (Identical Max W: 1)
# --------------------------------------------------
# === Node with self-loop: 'RUNX3' ===
#   ✅ Complete Cycle Match via neighbor 'IFNG':
#     - Path: RUNX3 -> IFNG -> IFNGR -> STAT1 -> SOCS1 -> STAT5 -> RUNX3 (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'IFNG_2':
#     - Path: RUNX3 -> IFNG_2 -> IFNGR -> STAT1 -> SOCS1 -> STAT5 -> RUNX3 (Identical Max W: 1)
#  ** Self-Loop unique to G -> (Max W: 4)
#   ✅ Complete Cycle Match via neighbor 'CD8':
#     - Path: RUNX3 -> CD8 -> RUNX3 (Identical Max W: 2)
#   ✅ Complete Cycle Match via neighbor 'IL4':
#     - Path: RUNX3 -> IL4 -> IL4R -> STAT5 -> RUNX3 (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'CD4':
#     - Path: RUNX3 -> CD4 -> THPOK -> RUNX3 (Identical Max W: 2)
#   ✅ Complete Cycle Match via neighbor 'EOMES':
#     - Path: RUNX3 -> EOMES -> IFNG -> IFNGR -> STAT1 -> SOCS1 -> STAT5 -> RUNX3 (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'THPOK':
#     - Path: RUNX3 -> THPOK -> RUNX3 (Identical Max W: 1)
# --------------------------------------------------
# === Node with self-loop: 'IFNGR' ===
#   ✅ Complete Cycle Match via neighbor 'JAK1':
#     - Path: IFNGR -> JAK1 -> STAT1 -> BCL6 -> IFNG -> IFNGR (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'STAT1_2':
#     - Path: IFNGR -> STAT1_2 -> BCL6 -> IFNG -> IFNGR (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'STAT1':
#     - Path: IFNGR -> STAT1 -> BCL6 -> IFNG -> IFNGR (Identical Max W: 1)
#  ** Self-Loop unique to G -> (Max W: 2)
#   ✅ Complete Cycle Match via neighbor 'IFNGR_2':
#     - Path: IFNGR -> IFNGR_2 -> STAT1 -> BCL6 -> IFNG -> IFNGR (Identical Max W: 1)
# --------------------------------------------------
# === Node with self-loop: 'proliferation' ===
#   ✅ Complete Cycle Match via neighbor 'IL10':
#     - Path: proliferation -> IL10 -> IL10R -> STAT3 -> CMAF -> IL4 -> IL4R -> STAT5 -> proliferation (Identical Max W: 4)
#   ✅ Complete Cycle Match via neighbor 'IFNG_2':
#     - Path: proliferation -> IFNG_2 -> IFNGR -> STAT1 -> SOCS1 -> STAT5 -> proliferation (Identical Max W: 4)
#   ✅ Complete Cycle Match via neighbor 'IFNG':
#     - Path: proliferation -> IFNG -> IFNGR -> STAT1 -> SOCS1 -> STAT5 -> proliferation (Identical Max W: 4)
#   ✅ Complete Cycle Match via neighbor 'IL6':
#     - Path: proliferation -> IL6 -> IL6R -> STAT3 -> CMAF -> IL4 -> IL4R -> STAT5 -> proliferation (Identical Max W: 4)
#   ✅ Complete Cycle Match via neighbor 'TGFB':
#     - Path: proliferation -> TGFB -> BCL6 -> GATA3 -> IL4 -> IL4R -> STAT5 -> proliferation (Identical Max W: 4)
#   ✅ Complete Cycle Match via neighbor 'IL25':
#     - Path: proliferation -> IL25 -> IL25R -> GATA3 -> IL4 -> IL4R -> STAT5 -> proliferation (Identical Max W: 4)
#   ⚠️ Route Discrepancy via neighbor 'IL9':
#     - G Path: proliferation -> IL9 -> IFNG -> IL2 -> IL2R -> STAT5 -> proliferation (Max W: 4)
#     - B Path: proliferation -> IL9 -> TBET -> IL2 -> IL2R -> STAT5 -> proliferation (Max W: 4)
#   ✅ Complete Cycle Match via neighbor 'IL4':
#     - Path: proliferation -> IL4 -> IL4R -> STAT5 -> proliferation (Identical Max W: 4)
#   ✅ Self-Loop Match -> Exists in both with identical Max W: 4
#   ✅ Complete Cycle Match via neighbor 'IL23':
#     - Path: proliferation -> IL23 -> IL23R -> STAT3 -> CMAF -> IL4 -> IL4R -> STAT5 -> proliferation (Identical Max W: 4)
#   ✅ Complete Cycle Match via neighbor 'IL21':
#     - Path: proliferation -> IL21 -> IL21R -> STAT3 -> CMAF -> IL4 -> IL4R -> STAT5 -> proliferation (Identical Max W: 4)
# --------------------------------------------------
# === Node with self-loop: 'FOXP3' ===
#   * Cycle via 'TBET' exists in G but missing in B (G Max W: 4)
#   * Cycle via 'IFNG_2' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'IFNG' exists in G but missing in B (G Max W: 2)
#   ✅ Complete Cycle Match via neighbor 'NFKB':
#     - Path: FOXP3 -> NFKB -> IL2 -> IL2R -> STAT5 -> FOXP3 (Identical Max W: 1)
#   * Cycle via 'TBET_2' exists in G but missing in B (G Max W: 4)
#   ✅ Complete Cycle Match via neighbor 'RORGT':
#     - Path: FOXP3 -> RORGT -> IL23R -> STAT3 -> BCL6 -> TBET -> FOXP3 (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'IL2RA':
#     - Path: FOXP3 -> IL2RA -> IL2R_2 -> STAT5 -> FOXP3 (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'IL2':
#     - Path: FOXP3 -> IL2 -> IL2R -> STAT5 -> FOXP3 (Identical Max W: 1)
#   * Cycle via 'IL4' exists in G but missing in B (G Max W: 2)
#   ✅ Complete Cycle Match via neighbor 'GATA3':
#     - Path: FOXP3 -> GATA3 -> TBET -> FOXP3 (Identical Max W: 1)
#   * Cycle via 'TGFB' exists in G but missing in B (G Max W: 3)
#   ✅ Complete Cycle Match via neighbor 'NFAT':
#     - Path: FOXP3 -> NFAT -> FOXP3 (Identical Max W: 1)
#  ** Self-Loop unique to G -> (Max W: 2)
#   * Cycle via 'THPOK' exists in G but missing in B (G Max W: 4)
# --------------------------------------------------
# === Node with self-loop: 'IL2' ===
#   * Cycle via 'BCL6' exists in G but missing in B (G Max W: 2)
#  ** Self-Loop unique to G -> (Max W: 2)
#   * Cycle via 'IL9' exists in G but missing in B (G Max W: 3)
#   ✅ Complete Cycle Match via neighbor 'IL2R_2':
#     - Path: IL2 -> IL2R_2 -> STAT5 -> FOXP3 -> IL2 (Identical Max W: 1)
#   * Cycle via 'IL4' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'GATA3' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'IL21' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'FOXP3' exists in G but missing in B (G Max W: 2)
#   ✅ Complete Cycle Match via neighbor 'IL2R':
#     - Path: IL2 -> IL2R -> STAT5 -> FOXP3 -> IL2 (Identical Max W: 1)
# --------------------------------------------------
# === Node with self-loop: 'TGFB' ===
#   ✅ Complete Cycle Match via neighbor 'BCL6':
#     - Path: TGFB -> BCL6 -> TBET -> FOXP3 -> NFAT -> TGFB (Identical Max W: 1)
#   * Cycle via 'IFNG' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'IFNG_2' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'IL10' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'IL9' exists in G but missing in B (G Max W: 3)
#   ✅ Complete Cycle Match via neighbor 'TGFBR':
#     - Path: TGFB -> TGFBR -> SMAD2 -> FOXP3 -> NFAT -> TGFB (Identical Max W: 1)
#   * Cycle via 'GATA3' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'RORGT' exists in G but missing in B (G Max W: 2)
#  ** Self-Loop unique to G -> (Max W: 2)
#   * Cycle via 'FOXP3' exists in G but missing in B (G Max W: 2)
# --------------------------------------------------
# === Node with self-loop: 'IL10' ===
#  ** Self-Loop unique to G -> (Max W: 2)
#   * Cycle via 'IFNG_2' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'IFNG' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'IL2' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'IL9' exists in G but missing in B (G Max W: 3)
#   ✅ Complete Cycle Match via neighbor 'IL10R':
#     - Path: IL10 -> IL10R -> STAT3 -> IL10 (Identical Max W: 1)
# --------------------------------------------------
# === Node with self-loop: 'IFNG' ===
#   * Cycle via 'TBET' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'IL10' exists in G but missing in B (G Max W: 2)
#   ✅ Complete Cycle Match via neighbor 'IFNG_2':
#     - Path: IFNG -> IFNG_2 -> IFNGR -> STAT1 -> BCL6 -> IFNG (Identical Max W: 1)
#  ** Self-Loop unique to G -> (Max W: 2)
#   * Cycle via 'IL2' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'IL9' exists in G but missing in B (G Max W: 3)
#   * Cycle via 'IL4' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'TBET_2' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'GATA3' exists in G but missing in B (G Max W: 2)
#   ✅ Complete Cycle Match via neighbor 'IFNGR':
#     - Path: IFNG -> IFNGR -> STAT1 -> BCL6 -> IFNG (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'IFNGR_2':
#     - Path: IFNG -> IFNGR_2 -> STAT1 -> BCL6 -> IFNG (Identical Max W: 1)
#   * Cycle via 'IL21' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'STAT6' exists in G but missing in B (G Max W: 2)
# --------------------------------------------------
# === Node with self-loop: 'CD4' ===
#   * Cycle via 'RUNX3' exists in G but missing in B (G Max W: 3)
#  ** Self-Loop unique to G -> (Max W: 4)
#   ✅ Complete Cycle Match via neighbor 'THPOK':
#     - Path: CD4 -> THPOK -> CD4 (Identical Max W: 2)
# --------------------------------------------------
# === Node with self-loop: 'TBET' ===
#  ** Self-Loop unique to G -> (Max W: 2)
#   ✅ Complete Cycle Match via neighbor 'IFNG':
#     - Path: TBET -> IFNG -> IFNGR -> STAT1 -> TBET (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'IFNG_2':
#     - Path: TBET -> IFNG_2 -> IFNGR -> STAT1 -> TBET (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'TBET_2':
#     - Path: TBET -> TBET_2 -> BCL6 -> TBET (Identical Max W: 1)
#   * Cycle via 'IL12R' exists in G but missing in B (G Max W: 2)
#   ✅ Complete Cycle Match via neighbor 'RORGT':
#     - Path: TBET -> RORGT -> IL23R -> STAT3 -> BCL6 -> TBET (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'BCL6':
#     - Path: TBET -> BCL6 -> TBET (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'IL2':
#     - Path: TBET -> IL2 -> IL2R -> STAT5 -> BCL6 -> TBET (Identical Max W: 1)
#   * Cycle via 'RUNX3' exists in G but missing in B (G Max W: 2)
#   ✅ Complete Cycle Match via neighbor 'IL4':
#     - Path: TBET -> IL4 -> IL4R -> STAT5 -> BCL6 -> TBET (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'IL23R':
#     - Path: TBET -> IL23R -> STAT3 -> BCL6 -> TBET (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'GATA3':
#     - Path: TBET -> GATA3 -> TBET (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'FOXP3':
#     - Path: TBET -> FOXP3 -> GATA3 -> TBET (Identical Max W: 1)
# --------------------------------------------------
# === Node with self-loop: 'STAT1' ===
#   ✅ Complete Cycle Match via neighbor 'IRF1':
#     - Path: STAT1 -> IRF1 -> IL12RB1_2 -> IL12R -> STAT4 -> IFNG -> IFNGR -> STAT1 (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'TBET':
#     - Path: STAT1 -> TBET -> IFNG -> IFNGR -> STAT1 (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'SOCS1':
#     - Path: STAT1 -> SOCS1 -> JAK1 -> STAT1 (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'BCL6':
#     - Path: STAT1 -> BCL6 -> IFNG -> IFNGR -> STAT1 (Identical Max W: 1)
#   * Cycle via 'IL4' exists in G but missing in B (G Max W: 2)
#   ✅ Complete Cycle Match via neighbor 'STAT1_2':
#     - Path: STAT1 -> STAT1_2 -> SOCS1 -> JAK1 -> STAT1 (Identical Max W: 1)
#   ✅ Self-Loop Match -> Exists in both with identical Max W: 1
#   ✅ Complete Cycle Match via neighbor 'TBET_2':
#     - Path: STAT1 -> TBET_2 -> IFNG -> IFNGR -> STAT1 (Identical Max W: 1)
#   * Cycle via 'FOXP3' exists in G but missing in B (G Max W: 2)
# --------------------------------------------------
# === Node with self-loop: 'TBET_2' ===
#   ✅ Complete Cycle Match via neighbor 'IFNG':
#     - Path: TBET_2 -> IFNG -> IFNGR -> STAT1 -> TBET_2 (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'IFNG_2':
#     - Path: TBET_2 -> IFNG_2 -> IFNGR -> STAT1 -> TBET_2 (Identical Max W: 1)
#  ** Self-Loop unique to G -> (Max W: 2)
#   * Cycle via 'IL12R' exists in G but missing in B (G Max W: 2)
#   ✅ Complete Cycle Match via neighbor 'RORGT':
#     - Path: TBET_2 -> RORGT -> IL23R -> STAT3 -> BCL6 -> TBET_2 (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'BCL6':
#     - Path: TBET_2 -> BCL6 -> TBET_2 (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'IL2':
#     - Path: TBET_2 -> IL2 -> IL2R -> STAT5 -> BCL6 -> TBET_2 (Identical Max W: 1)
#   * Cycle via 'RUNX3' exists in G but missing in B (G Max W: 2)
#   ✅ Complete Cycle Match via neighbor 'IL4':
#     - Path: TBET_2 -> IL4 -> IL4R -> STAT5 -> BCL6 -> TBET_2 (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'IL23R':
#     - Path: TBET_2 -> IL23R -> STAT3 -> BCL6 -> TBET_2 (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'GATA3':
#     - Path: TBET_2 -> GATA3 -> TBET_2 (Identical Max W: 1)
#   ✅ Complete Cycle Match via neighbor 'FOXP3':
#     - Path: TBET_2 -> FOXP3 -> GATA3 -> TBET_2 (Identical Max W: 1)
# --------------------------------------------------
# === Node with self-loop: 'IL4' ===
#   * Cycle via 'TBET' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'IFNG_2' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'IFNG' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'IL9' exists in G but missing in B (G Max W: 3)
#   ✅ Complete Cycle Match via neighbor 'IL4R_2':
#     - Path: IL4 -> IL4R_2 -> STAT5_2 -> GATA3 -> IL4 (Identical Max W: 1)
#  ** Self-Loop unique to G -> (Max W: 2)
#   ✅ Complete Cycle Match via neighbor 'IL4R':
#     - Path: IL4 -> IL4R -> STAT5 -> IL4 (Identical Max W: 1)
#   * Cycle via 'TBET_2' exists in G but missing in B (G Max W: 2)
#   * Cycle via 'GATA3' exists in G but missing in B (G Max W: 2)
# --------------------------------------------------

# %%
print_report(G)
print()
print_report(B2)
# Out:
# Number of nodes: 106
# Number of edges: 430
# node with highest in-degree:  IFNG_2  with in-degree:  23
# number of possible Boolean Networks: 2^ 13840246
#
# Number of nodes: 106
# Number of edges: 291
# node with highest in-degree:  IFNG_2  with in-degree:  14
# number of possible Boolean Networks: 2^ 31634

# %%
# 2. Map Graph B edges into a dictionary for instant lookups
edges_B2_dict = {}
for u, v, data in B2.edges(data=True):
    # Checks both common attribute names ('weight' or 'distance')
    weight_val = data.get('weight') or data.get('distance')
    edges_B2_dict[(str(u), str(v))] = weight_val

# 3. Stream through the input CSV and write to both outputs simultaneously
matching_rows_count = 0
total_rows_count = 0
line_number = 1

with open(csv_file_path, mode='r', encoding='utf-8') as infile, \
     open(output_csv_path, mode='w', encoding='utf-8', newline='') as filtered_file, \
     open(annotated_csv_path, mode='w', encoding='utf-8', newline='') as annotated_file:
    
    reader = csv.DictReader(infile)
    
    # Setup Output 1: Filtered file (identical columns to input)
    filtered_writer = csv.DictWriter(filtered_file, fieldnames=reader.fieldnames)
    filtered_writer.writeheader()
    
    # Setup Output 2: Annotated file (input columns + the new extra status column)
    annotated_fieldnames = list(reader.fieldnames) + ['is_kept']
    annotated_writer = csv.DictWriter(annotated_file, fieldnames=annotated_fieldnames)
    annotated_writer.writeheader()
    
    for row in reader:
        line_number += 1
        total_rows_count += 1
        
        row_src = str(row[source_col])
        row_tgt = str(row[target_col])
        
        try:
            # Change int() to float() if your weights contain decimals
            row_weight = int(row[weight_col]) 
            is_valid_weight = True
        except (ValueError, TypeError):
            print(f"⚠️ Warning: Non-numeric weight skipped on line {line_number}.", file=sys.stderr)
            is_valid_weight = False
            
        edge_key = (row_src, row_tgt)
        is_kept = False
        
        # Evaluate if the edge matches Graph B criteria
        if is_valid_weight and (edge_key in edges_B2_dict):
            graph_weight = edges_B2_dict[edge_key]
            
            if row_weight == graph_weight:
                is_kept = True
            else:
                print(f"⚠️ Weight Mismatch Warning [Line {line_number}]: Connection ({row_src} -> {row_tgt}) "
                      f"found in B, but weights disagree! (CSV: {row_weight} vs Graph B: {graph_weight})")
        
        # --- Handle Output 1 (Filtered) ---
        if is_kept:
            filtered_writer.writerow(row)
            matching_rows_count += 1
            
        # --- Handle Output 2 (Annotated) ---
        # Make a copy of the row so we don't accidentally modify the row data used by other operations
        annotated_row = dict(row)
        annotated_row['is_kept'] = "KEPT" if is_kept else "TAKEN_OUT"
        annotated_writer.writerow(annotated_row)

print("\n🎉 Done! Processing completed successfully.")
print(f"   * Total original rows processed: {total_rows_count}")
print(f"   * Filtered output created: '{output_csv_path}' ({matching_rows_count} rows)")
print(f"   * Annotated output created: '{annotated_csv_path}' ({total_rows_count} rows)")
# Out:
# 🎉 Done! Processing completed successfully.
#    * Total original rows processed: 430
#    * Filtered output created: 'confidence_rank_ultrametric.csv' (291 rows)
#    * Annotated output created: 'confidence_rank_unique_annotated.csv' (430 rows)
