# %%
from boolmore.io.load import import_phenotypes

# %%
path = "./input.csv"

# %%
data = import_phenotypes(path)

print(len(data))
for d in data:
    print(d)
    break
# Out:
# 83
# Experiment(id=1, perturbation=(), sources=(('APC', 0), ('DLL1', 0), ('IFNA_e', 0), ('IFNG_e', 0), ('IL10_e', 0), ('IL15_e', 0), ('IL1_e', 0), ('IL21_e', 0), ('IL23_e', 0), ('IL25_e', 0), ('IL27_e', 0), ('IL29_e', 0), ('IL2_e', 0), ('IL33_e', 0), ('IL36_e', 0), ('IL4_e', 0), ('IL6_e', 0), ('IL7_e', 0), ('TGFB_e', 0)), phenotype=(('GATA3', 0), ('IFNG', 0), ('IL4', 0), ('TBET', 0)), expected_exists=True, weight=1.0)
