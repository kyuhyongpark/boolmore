# %%
import os

from pyboolnet.external.bnet2primes import bnet_file2primes
from pyboolnet.external.bnet2primes import bnet_text2primes

from boolmore.experiment import import_exps
from boolmore.model import Model

# %%
DATA = "ABA_A_gitsbe.tsv"
DEFAULT_SOURCES = {"ABA":0}

print("Loading experimental data . . .")
exps, pert = import_exps(DATA)
print("Experimental data loaded.\n")
# Out:
# Loading experimental data . . .
# Experimental data loaded.

# %%
# score all models generated by Gitsbe

gitsbe_directory = "ABA_A_20241105_214621/models"
gitsbe_dict = {}

n = 0
for filename in os.listdir(gitsbe_directory):
    if filename.endswith(".bnet"):
        print(filename)
        primes = bnet_file2primes(os.path.join(gitsbe_directory, filename))

        n1 = Model.import_model(primes, default_sources=DEFAULT_SOURCES)
        n1.get_predictions(pert)
        n1.get_model_score(exps)

        gitsbe_dict[filename] = n1

        n += 1

    # break

print("Scored", n, "models from Gitsbe.")
# Out:
# ABA_A_network_run_0__G399_M138.bnet
# ABA_A_network_run_0__G399_M200.bnet
# ABA_A_network_run_0__G399_M275.bnet
# ABA_A_network_run_1__G399_M183.bnet
# ABA_A_network_run_1__G399_M216.bnet
# ABA_A_network_run_1__G399_M260.bnet
# ABA_A_network_run_2__G399_M143.bnet
# ABA_A_network_run_2__G399_M379.bnet
# ABA_A_network_run_2__G399_M86.bnet
# ABA_A_network_run_3__G399_M152.bnet
# ABA_A_network_run_3__G399_M394.bnet
# ABA_A_network_run_3__G399_M66.bnet
# ABA_A_network_run_4__G399_M357.bnet
# ABA_A_network_run_4__G399_M378.bnet
# ABA_A_network_run_4__G399_M394.bnet
# ABA_A_network_run_5__G399_M122.bnet
# ABA_A_network_run_5__G399_M36.bnet
# ABA_A_network_run_5__G399_M89.bnet
# Scored 18 models from Gitsbe.

# %%
# score all models generated by boolmore

boolmore_directory = "../../case_study/generated_models/repetitions"
boolmore_dict = {}

n = 0

for filename in os.listdir(boolmore_directory):
    if filename.endswith(".bnet"):
        print(filename)

        # read the whole file
        fp = open(boolmore_directory + "/" + filename, "r")
        text = fp.read()
        fp.close()

        # replace text
        text = text.replace("8-nitro-cGMP", "nitro_cGMP")
        text = text.replace("V-PPase", "V_PPase")
        text = text.replace("V-ATPase", "V_ATPase")

        primes = bnet_text2primes(text)

        n1 = Model.import_model(primes, default_sources=DEFAULT_SOURCES)
        n1.get_predictions(pert)
        n1.get_model_score(exps)

        boolmore_dict[filename] = n1

        n += 1

    # break

print("Scored", n, "models from boolmore.")
# Out:
# 20241007143135_9306_gen124.bnet
# 20241009072111_9984_gen68.bnet
# 20241009211257_9880_gen154.bnet
# 20241010082016_9453_gen140.bnet
# 20241011222037_9848_gen50.bnet
# 20241014130450_9902_gen56.bnet
# rep_20230917_7545_gen112.bnet
# rep_20230918_7560_gen105.bnet
# rep_20230919_8030_gen113.bnet
# rep_20230920_7788_gen121.bnet
# rep_20230921_7687_gen104.bnet
# rep_20230922_8036_gen125.bnet
# rep_20230923_8025_gen141.bnet
# rep_20230924_8037_gen129.bnet
# rep_20230925_7821_gen113.bnet
# Scored 15 models from boolmore.

# %%
# make pandas dataframe

import pandas as pd


pandas_dict = {}

for filename in gitsbe_dict:
    pandas_dict[filename] = ["Gitsbe", gitsbe_dict[filename].score, gitsbe_dict[filename].non_hierarchy_score, gitsbe_dict[filename].max_score]

for filename in boolmore_dict:
    pandas_dict[filename] = ["boolmore", boolmore_dict[filename].score, boolmore_dict[filename].non_hierarchy_score, boolmore_dict[filename].max_score]

df = pd.DataFrame.from_dict(pandas_dict, orient="index")

df.columns = ["Method", "hierarchy score", "non-hierarchy score", "max score"]

df["hierarchy score(%)"] = df["hierarchy score"] / df["max score"] * 100

df["non-hierarchy score(%)"] = df["non-hierarchy score"] / df["max score"] * 100

df
# Out:
#                                        Method  hierarchy score  \
# ABA_A_network_run_0__G399_M138.bnet    Gitsbe       304.189894
# ABA_A_network_run_0__G399_M200.bnet    Gitsbe       304.248717
# ABA_A_network_run_0__G399_M275.bnet    Gitsbe       304.248717
# ABA_A_network_run_1__G399_M183.bnet    Gitsbe       304.304081
# ABA_A_network_run_1__G399_M216.bnet    Gitsbe       302.999198
# ABA_A_network_run_1__G399_M260.bnet    Gitsbe       304.430186
# ABA_A_network_run_2__G399_M143.bnet    Gitsbe       303.927302
# ABA_A_network_run_2__G399_M379.bnet    Gitsbe       304.985741
# ABA_A_network_run_2__G399_M86.bnet     Gitsbe       304.121458
# ABA_A_network_run_3__G399_M152.bnet    Gitsbe       301.262969
# ABA_A_network_run_3__G399_M394.bnet    Gitsbe       304.559751
# ABA_A_network_run_3__G399_M66.bnet     Gitsbe       303.530473
# ABA_A_network_run_4__G399_M357.bnet    Gitsbe       303.860405
# ABA_A_network_run_4__G399_M378.bnet    Gitsbe       303.968440
# ABA_A_network_run_4__G399_M394.bnet    Gitsbe       303.919229
# ABA_A_network_run_5__G399_M122.bnet    Gitsbe       304.993046
# ABA_A_network_run_5__G399_M36.bnet     Gitsbe       304.968440
# ABA_A_network_run_5__G399_M89.bnet     Gitsbe       304.968440
# 20241007143135_9306_gen124.bnet      boolmore       355.944444
# 20241009072111_9984_gen68.bnet       boolmore       362.091837
# 20241009211257_9880_gen154.bnet      boolmore       352.070387
# 20241010082016_9453_gen140.bnet      boolmore       351.779337
# 20241011222037_9848_gen50.bnet       boolmore       336.978889
# 20241014130450_9902_gen56.bnet       boolmore       334.277778
# rep_20230917_7545_gen112.bnet        boolmore       343.311111
# rep_20230918_7560_gen105.bnet        boolmore       341.990000
# rep_20230919_8030_gen113.bnet        boolmore       344.833333
# rep_20230920_7788_gen121.bnet        boolmore       348.703651
# rep_20230921_7687_gen104.bnet        boolmore       335.832540
# rep_20230922_8036_gen125.bnet        boolmore       354.750000
# rep_20230923_8025_gen141.bnet        boolmore       355.983333
# rep_20230924_8037_gen129.bnet        boolmore       353.527778
# rep_20230925_7821_gen113.bnet        boolmore       335.916667
#
#                                      non-hierarchy score  max score  \
# ABA_A_network_run_0__G399_M138.bnet           341.261438      429.0
# ABA_A_network_run_0__G399_M200.bnet           341.215686      429.0
# ABA_A_network_run_0__G399_M275.bnet           341.215686      429.0
# ABA_A_network_run_1__G399_M183.bnet           340.037908      429.0
# ABA_A_network_run_1__G399_M216.bnet           339.895425      429.0
# ABA_A_network_run_1__G399_M260.bnet           340.849673      429.0
# ABA_A_network_run_2__G399_M143.bnet           340.065359      429.0
# ABA_A_network_run_2__G399_M379.bnet           342.209150      429.0
# ABA_A_network_run_2__G399_M86.bnet            340.372549      429.0
# ABA_A_network_run_3__G399_M152.bnet           343.675946      429.0
# ABA_A_network_run_3__G399_M394.bnet           340.588235      429.0
# ABA_A_network_run_3__G399_M66.bnet            340.198592      429.0
# ABA_A_network_run_4__G399_M357.bnet           340.810458      429.0
# ABA_A_network_run_4__G399_M378.bnet           341.026144      429.0
# ABA_A_network_run_4__G399_M394.bnet           340.869281      429.0
# ABA_A_network_run_5__G399_M122.bnet           340.947712      429.0
# ABA_A_network_run_5__G399_M36.bnet            340.921569      429.0
# ABA_A_network_run_5__G399_M89.bnet            341.026144      429.0
# 20241007143135_9306_gen124.bnet               374.500000      429.0
# 20241009072111_9984_gen68.bnet                374.464286      429.0
# 20241009211257_9880_gen154.bnet               371.938095      429.0
# 20241010082016_9453_gen140.bnet               374.276786      429.0
# 20241011222037_9848_gen50.bnet                360.100000      429.0
# 20241014130450_9902_gen56.bnet                359.333333      429.0
# rep_20230917_7545_gen112.bnet                 366.833333      429.0
# rep_20230918_7560_gen105.bnet                 365.100000      429.0
# rep_20230919_8030_gen113.bnet                 362.966667      429.0
# rep_20230920_7788_gen121.bnet                 366.971429      429.0
# rep_20230921_7687_gen104.bnet                 365.282540      429.0
# rep_20230922_8036_gen125.bnet                 371.000000      429.0
# rep_20230923_8025_gen141.bnet                 370.616667      429.0
# rep_20230924_8037_gen129.bnet                 366.916667      429.0
# rep_20230925_7821_gen113.bnet                 361.700000      429.0
#
#                                      hierarchy score(%)  \
# ABA_A_network_run_0__G399_M138.bnet           70.906735
# ABA_A_network_run_0__G399_M200.bnet           70.920447
# ABA_A_network_run_0__G399_M275.bnet           70.920447
# ABA_A_network_run_1__G399_M183.bnet           70.933352
# ABA_A_network_run_1__G399_M216.bnet           70.629184
# ABA_A_network_run_1__G399_M260.bnet           70.962747
# ABA_A_network_run_2__G399_M143.bnet           70.845525
# ABA_A_network_run_2__G399_M379.bnet           71.092247
# ABA_A_network_run_2__G399_M86.bnet            70.890783
# ABA_A_network_run_3__G399_M152.bnet           70.224468
# ABA_A_network_run_3__G399_M394.bnet           70.992949
# ABA_A_network_run_3__G399_M66.bnet            70.753024
# ABA_A_network_run_4__G399_M357.bnet           70.829931
# ABA_A_network_run_4__G399_M378.bnet           70.855114
# ABA_A_network_run_4__G399_M394.bnet           70.843643
# ABA_A_network_run_5__G399_M122.bnet           71.093950
# ABA_A_network_run_5__G399_M36.bnet            71.088215
# ABA_A_network_run_5__G399_M89.bnet            71.088215
# 20241007143135_9306_gen124.bnet               82.970733
# 20241009072111_9984_gen68.bnet                84.403692
# 20241009211257_9880_gen154.bnet               82.067689
# 20241010082016_9453_gen140.bnet               81.999845
# 20241011222037_9848_gen50.bnet                78.549858
# 20241014130450_9902_gen56.bnet                77.920228
# rep_20230917_7545_gen112.bnet                 80.025900
# rep_20230918_7560_gen105.bnet                 79.717949
# rep_20230919_8030_gen113.bnet                 80.380730
# rep_20230920_7788_gen121.bnet                 81.282902
# rep_20230921_7687_gen104.bnet                 78.282643
# rep_20230922_8036_gen125.bnet                 82.692308
# rep_20230923_8025_gen141.bnet                 82.979798
# rep_20230924_8037_gen129.bnet                 82.407407
# rep_20230925_7821_gen113.bnet                 78.302253
#
#                                      non-hierarchy score(%)
# ABA_A_network_run_0__G399_M138.bnet               79.548121
# ABA_A_network_run_0__G399_M200.bnet               79.537456
# ABA_A_network_run_0__G399_M275.bnet               79.537456
# ABA_A_network_run_1__G399_M183.bnet               79.262916
# ABA_A_network_run_1__G399_M216.bnet               79.229703
# ABA_A_network_run_1__G399_M260.bnet               79.452138
# ABA_A_network_run_2__G399_M143.bnet               79.269315
# ABA_A_network_run_2__G399_M379.bnet               79.769033
# ABA_A_network_run_2__G399_M86.bnet                79.340921
# ABA_A_network_run_3__G399_M152.bnet               80.110943
# ABA_A_network_run_3__G399_M394.bnet               79.391197
# ABA_A_network_run_3__G399_M66.bnet                79.300371
# ABA_A_network_run_4__G399_M357.bnet               79.442997
# ABA_A_network_run_4__G399_M378.bnet               79.493274
# ABA_A_network_run_4__G399_M394.bnet               79.456709
# ABA_A_network_run_5__G399_M122.bnet               79.474991
# ABA_A_network_run_5__G399_M36.bnet                79.468897
# ABA_A_network_run_5__G399_M89.bnet                79.493274
# 20241007143135_9306_gen124.bnet                   87.296037
# 20241009072111_9984_gen68.bnet                    87.287712
# 20241009211257_9880_gen154.bnet                   86.698857
# 20241010082016_9453_gen140.bnet                   87.244006
# 20241011222037_9848_gen50.bnet                    83.939394
# 20241014130450_9902_gen56.bnet                    83.760684
# rep_20230917_7545_gen112.bnet                     85.508936
# rep_20230918_7560_gen105.bnet                     85.104895
# rep_20230919_8030_gen113.bnet                     84.607615
# rep_20230920_7788_gen121.bnet                     85.541126
# rep_20230921_7687_gen104.bnet                     85.147445
# rep_20230922_8036_gen125.bnet                     86.480186
# rep_20230923_8025_gen141.bnet                     86.390831
# rep_20230924_8037_gen129.bnet                     85.528361
# rep_20230925_7821_gen113.bnet                     84.312354

# %%
Gitsbe_max_h_score = round(df[df["Method"] == "Gitsbe"]["hierarchy score"].max(), 1)
Gitsbe_max_h_score_p = round(df[df["Method"] == "Gitsbe"]["hierarchy score(%)"].max(), 1)
Gitsbe_max_nh_score = round(df[df["Method"] == "Gitsbe"]["non-hierarchy score"].max(), 1)
Gitsbe_max_nh_score_p = round(df[df["Method"] == "Gitsbe"]["non-hierarchy score(%)"].max(), 1)
n_Gitsbe = len(df[df["Method"] == "Gitsbe"])

boolmore_min_h_score = round(df[df["Method"] == "boolmore"]["hierarchy score"].min(), 1)
boolmore_min_h_score_p = round(df[df["Method"] == "boolmore"]["hierarchy score(%)"].min(), 1)
boolmore_min_nh_score = round(df[df["Method"] == "boolmore"]["non-hierarchy score"].min(), 1)
boolmore_min_nh_score_p = round(df[df["Method"] == "boolmore"]["non-hierarchy score(%)"].min(), 1)
n_boolmore = len(df[df["Method"] == "boolmore"])

data = {
    "Gitsbe max": [n_Gitsbe, Gitsbe_max_h_score, Gitsbe_max_h_score_p, Gitsbe_max_nh_score, Gitsbe_max_nh_score_p],
    "boolmore min": [n_boolmore, boolmore_min_h_score, boolmore_min_h_score_p, boolmore_min_nh_score, boolmore_min_nh_score_p]
    }

table = pd.DataFrame.from_dict(data, orient="index")
table.columns = ["number of models", "score", "score(%)", "non-hierarchy score", "non-hierarchy score(%)"]

table
# Out:
#               number of models  score  score(%)  non-hierarchy score  \
# Gitsbe max                  18  305.0      71.1                343.7
# boolmore min                15  334.3      77.9                359.3
#
#               non-hierarchy score(%)
# Gitsbe max                      80.1
# boolmore min                    83.8
